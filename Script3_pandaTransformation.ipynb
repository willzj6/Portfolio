# %% [markdown]
# # Transforming datasets (Laptop, CPU, GPU)
#
# This notebook transforms the:
#
# * laptop data scraped from Scorptec
#
# * cpu data scraped from Passmark
#
# * gpu data from Passmark downloaded from: https://www.kaggle.com/datasets/alanjo/gpu-benchmarks
#
# To be compatible and usable for the oncoming analysis.
#
#
# The overall goal of this is to make matching cpu and gpu components with their benchmark data straightforward, and create columns for better querying.
#
# Information about each transformation will be under their heading.

# %%
import pandas as pd
import numpy as np
import os, re, json

cwd = os.getcwd()

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Laptop data transformation
# Create columns for the laptop brand, cpu brand, and gpu brand.
#
# Modify the cpu and gpu columns so they match the keys of the cpu and gpu datasets
#
# Make the display size, memory, and storage size queryable as int.

# %%
laptop_original = pd.read_csv(cwd + '/datasets/laptop_data/scorptec2023-04-07.csv', quotechar="'")
laptop_modify = laptop_original.copy()
laptop_modify
# Out:
#                                                   NAME  \
# 0    Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1    Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2    MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3    MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4    MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
# ..                                                 ...
# 683  Lenovo ThinkPad P15v G3 15.6 inch FHD i7 16GB ...
# 684  MSI Creator M16 A12UC 16 inch i7 RTX3050 Win11...
# 685  MSI CreatorPro Z17 A12UMST 17" Core i7 32GB 1T...
# 686  MSI CreatorPro X17HX A13VKS 17.3inch Core i9 6...
# 687  MSI CreatorPro Z17 HX Studio A13VKT 17" i7 64G...
#
#                              PRODUCTCODE  PRICE        PROCESSOR  \
# 0                        A5 K1-AAU1130SB   1799    Ryzen 5-5600H
# 1                     RZ09-0427NEA3-R3B1   2699   Ryzen 9-6900HX
# 2                 Katana GF66 12UD-069AU   1549        i7-12700H
# 3                 Katana GF76 12UE-019AU   1899        i7-12700H
# 4                  GF63 Thin 11SC-1095AU    999        i5-11400H
# ..                                   ...    ...              ...
# 683                           21D80022AU   2699   Core i7-12700H
# 684              Creator M16 A12UC-237AU   2399   Core i7-12700H
# 685         CreatorPro Z17 A12UMST-218AU   6599   Core i7-12700H
# 686        CreatorPro X17HX A13VKS-204AU   9599  Core i9-13980HX
# 687  CreatorPro Z17HXStudio A13VKT-052AU   7999  Core i9-13950HX
#
#               MEMORY                       GRAPHICS  \
# 0         16GB , RAM  GeForce RTX 3060 Max-P Design
# 1      16GB DDR5 RAM        GeForce RTX 3070 Ti 8GB
# 2    16GB , DDR4 RAM            GeForce RTX 3050 Ti
# 3         16GB , RAM           GeForce RTX 3060 6GB
# 4          8GB , RAM           GeForce GTX 1650 4GB
# ..               ...                            ...
# 683  16GB RAM DDR5 ,                Nvidia T600 4GB
# 684       16GB RAM ,                    RTX3050 4GB
# 685  32GB DDR5 RAM ,                 RTX A5500 16GB
# 686  64GB DDR5 RAM ,                  RTX 3500 12GB
# 687  64GB DDR5 RAM ,                   RTX 3000 8GB
#
#                           STORAGE                        DISPLAY
# 0              512GB M.2 PCIE SSD             15.6inch FHD 144Hz
# 1                1TB M.2 PCIE SSD               14inch QHD 165Hz
# 2                1TB M.2 PCIE SSD             15.6inch FHD 144Hz
# 3                1TB M.2 PCIE SSD             17.3inch FHD 144Hz
# 4              512GB M.2 PCIE SSD                   15.6inch FHD
# ..                            ...                            ...
# 683                 512GB M.2 SSD              15.6 inch FHD IPS
# 684                     512GB SSD              16 inch QHD+ 60Hz
# 685    1TB M.2 NVMe PCIe Gen4 SSD              17inch QHD+ 165Hz
# 686  4TB , M.2 NVMe PCIe Gen4 SSD             17.3inch UHD 144Hz
# 687    2TB M.2 NVMe PCIe Gen4 SSD  17inch QHD+ 165Hz Touchscreen
#
# [688 rows x 8 columns]

# %%
# Create column for laptop brand
brandsSeries = laptop_modify.NAME.str.split(n=1, expand=True)[0]
brandsSeries.name = 'LAPTOP_BRAND'
laptop_modify = pd.concat([brandsSeries, laptop_modify], axis='columns')
laptop_modify.head()
# Out:
#   LAPTOP_BRAND                                               NAME  \
# 0     Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1        Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2          MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3          MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4          MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
#
#               PRODUCTCODE  PRICE       PROCESSOR           MEMORY  \
# 0         A5 K1-AAU1130SB   1799   Ryzen 5-5600H       16GB , RAM
# 1      RZ09-0427NEA3-R3B1   2699  Ryzen 9-6900HX    16GB DDR5 RAM
# 2  Katana GF66 12UD-069AU   1549       i7-12700H  16GB , DDR4 RAM
# 3  Katana GF76 12UE-019AU   1899       i7-12700H       16GB , RAM
# 4   GF63 Thin 11SC-1095AU    999       i5-11400H        8GB , RAM
#
#                         GRAPHICS             STORAGE             DISPLAY
# 0  GeForce RTX 3060 Max-P Design  512GB M.2 PCIE SSD  15.6inch FHD 144Hz
# 1        GeForce RTX 3070 Ti 8GB    1TB M.2 PCIE SSD    14inch QHD 165Hz
# 2            GeForce RTX 3050 Ti    1TB M.2 PCIE SSD  15.6inch FHD 144Hz
# 3           GeForce RTX 3060 6GB    1TB M.2 PCIE SSD  17.3inch FHD 144Hz
# 4           GeForce GTX 1650 4GB  512GB M.2 PCIE SSD        15.6inch FHD

# %%
# Create column for CPU brand
cpu_Conditions = [
    laptop_modify.PROCESSOR.str.contains('Intel|(i\d(-|\s))', case=False),
    laptop_modify.PROCESSOR.str.contains('AMD|Ryzen|R\d', case=False),
    laptop_modify.LAPTOP_BRAND == 'Apple'
]
cpu_Values = ['Intel', 'AMD', 'Apple']
laptop_modify['CPU_BRAND'] = np.select(cpu_Conditions, cpu_Values, default='Unknown')

laptop_modify.head()
# Out:
# /var/folders/sl/05d_jpr94jv0p51sn01y__x00000gn/T/ipykernel_13439/1165048059.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   laptop_modify.PROCESSOR.str.contains('Intel|(i\d(-|\s))', case=False),
#   LAPTOP_BRAND                                               NAME  \
# 0     Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1        Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2          MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3          MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4          MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
#
#               PRODUCTCODE  PRICE       PROCESSOR           MEMORY  \
# 0         A5 K1-AAU1130SB   1799   Ryzen 5-5600H       16GB , RAM
# 1      RZ09-0427NEA3-R3B1   2699  Ryzen 9-6900HX    16GB DDR5 RAM
# 2  Katana GF66 12UD-069AU   1549       i7-12700H  16GB , DDR4 RAM
# 3  Katana GF76 12UE-019AU   1899       i7-12700H       16GB , RAM
# 4   GF63 Thin 11SC-1095AU    999       i5-11400H        8GB , RAM
#
#                         GRAPHICS             STORAGE             DISPLAY  \
# 0  GeForce RTX 3060 Max-P Design  512GB M.2 PCIE SSD  15.6inch FHD 144Hz
# 1        GeForce RTX 3070 Ti 8GB    1TB M.2 PCIE SSD    14inch QHD 165Hz
# 2            GeForce RTX 3050 Ti    1TB M.2 PCIE SSD  15.6inch FHD 144Hz
# 3           GeForce RTX 3060 6GB    1TB M.2 PCIE SSD  17.3inch FHD 144Hz
# 4           GeForce GTX 1650 4GB  512GB M.2 PCIE SSD        15.6inch FHD
#
#   CPU_BRAND
# 0       AMD
# 1       AMD
# 2     Intel
# 3     Intel
# 4     Intel

# %%
# Extract cpu model
intel_regex = r'\b(([A-Z][A-Z0-9-]*|i.*)?\d{3,}\w*)'
amd_regex = r'\b(([A-Z]+-)?\d{3,}\w*)'
apple_regex = r'\b(M\d.*Core)'

def extract_laptop_cpu(row):
    processor = row.PROCESSOR
    cpuBrand = row.CPU_BRAND

    if cpuBrand == 'Intel':
        modelMatch = re.search(intel_regex, processor)
        if modelMatch != None:
            return modelMatch.group(0)

    elif cpuBrand == 'AMD':
        modelMatch = re.search(amd_regex, processor)
        if modelMatch != None:
            return modelMatch.group(0)

    elif cpuBrand == 'Apple':
        modelMatch = re.search(apple_regex, processor)
        if modelMatch != None:
            return modelMatch.group(0)

    return processor

laptop_modify['CPU_MODEL'] = laptop_modify.apply(extract_laptop_cpu, axis = 1)
laptop_modify.head()
# Out:
#   LAPTOP_BRAND                                               NAME  \
# 0     Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1        Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2          MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3          MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4          MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
#
#               PRODUCTCODE  PRICE       PROCESSOR           MEMORY  \
# 0         A5 K1-AAU1130SB   1799   Ryzen 5-5600H       16GB , RAM
# 1      RZ09-0427NEA3-R3B1   2699  Ryzen 9-6900HX    16GB DDR5 RAM
# 2  Katana GF66 12UD-069AU   1549       i7-12700H  16GB , DDR4 RAM
# 3  Katana GF76 12UE-019AU   1899       i7-12700H       16GB , RAM
# 4   GF63 Thin 11SC-1095AU    999       i5-11400H        8GB , RAM
#
#                         GRAPHICS             STORAGE             DISPLAY  \
# 0  GeForce RTX 3060 Max-P Design  512GB M.2 PCIE SSD  15.6inch FHD 144Hz
# 1        GeForce RTX 3070 Ti 8GB    1TB M.2 PCIE SSD    14inch QHD 165Hz
# 2            GeForce RTX 3050 Ti    1TB M.2 PCIE SSD  15.6inch FHD 144Hz
# 3           GeForce RTX 3060 6GB    1TB M.2 PCIE SSD  17.3inch FHD 144Hz
# 4           GeForce GTX 1650 4GB  512GB M.2 PCIE SSD        15.6inch FHD
#
#   CPU_BRAND  CPU_MODEL
# 0       AMD      5600H
# 1       AMD     6900HX
# 2     Intel  i7-12700H
# 3     Intel  i7-12700H
# 4     Intel  i5-11400H

# %%
# Create gpu brand column
gpu_Conditions = [
    laptop_modify.GRAPHICS.str.contains('Intel|UHD|Iris|Irix', case = False),
    laptop_modify.GRAPHICS.str.contains('Nvidia|GeForce|GTX|MX|Quadro', case = False),
    laptop_modify.GRAPHICS.str.contains('AMD|Radeon|RTX', case=False),
    laptop_modify.LAPTOP_BRAND == 'Apple'
]
gpu_Values = ['Intel', 'Nvidia', 'AMD', 'Apple']

laptop_modify['GPU_BRAND'] = np.select(gpu_Conditions, gpu_Values, default='Unknown')
laptop_modify.head()
# Out:
#   LAPTOP_BRAND                                               NAME  \
# 0     Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1        Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2          MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3          MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4          MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
#
#               PRODUCTCODE  PRICE       PROCESSOR           MEMORY  \
# 0         A5 K1-AAU1130SB   1799   Ryzen 5-5600H       16GB , RAM
# 1      RZ09-0427NEA3-R3B1   2699  Ryzen 9-6900HX    16GB DDR5 RAM
# 2  Katana GF66 12UD-069AU   1549       i7-12700H  16GB , DDR4 RAM
# 3  Katana GF76 12UE-019AU   1899       i7-12700H       16GB , RAM
# 4   GF63 Thin 11SC-1095AU    999       i5-11400H        8GB , RAM
#
#                         GRAPHICS             STORAGE             DISPLAY  \
# 0  GeForce RTX 3060 Max-P Design  512GB M.2 PCIE SSD  15.6inch FHD 144Hz
# 1        GeForce RTX 3070 Ti 8GB    1TB M.2 PCIE SSD    14inch QHD 165Hz
# 2            GeForce RTX 3050 Ti    1TB M.2 PCIE SSD  15.6inch FHD 144Hz
# 3           GeForce RTX 3060 6GB    1TB M.2 PCIE SSD  17.3inch FHD 144Hz
# 4           GeForce GTX 1650 4GB  512GB M.2 PCIE SSD        15.6inch FHD
#
#   CPU_BRAND  CPU_MODEL GPU_BRAND
# 0       AMD      5600H    Nvidia
# 1       AMD     6900HX    Nvidia
# 2     Intel  i7-12700H    Nvidia
# 3     Intel  i7-12700H    Nvidia
# 4     Intel  i5-11400H    Nvidia

# %%
# Load in UHD Data
# UHD_Graphics.json contains the UHD Generation each UHD Intel Chip belongs to
f = open('UHD_Graphics.json')
UHD_Data = json.load(f)
f.close()

# %%
# Extract gpu model
def extract_laptop_gpu(row):
    gpu_regex = r'\b[A-Z0-9-]*\d\d[A-Z0-9-]*\b'
    brand = row.GPU_BRAND
    name = row.GRAPHICS

    if brand == 'Nvidia':
        gpu_model = re.search(gpu_regex, name)
        if gpu_model != None:
            gpu_model = gpu_model.group(0)
            if 'Ti' in name:
                gpu_model += ' Ti'
            if 'Super' in name:
                gpu_model += ' Super'
            return gpu_model
        elif 'Ti' in name:
            gpuNameList = name.split('Ti')
            gpu_model = re.search(gpu_regex, gpuNameList[0]).group(0)
            gpu_model += ' Ti'
            return gpu_model
        else:
            return 'Unknown'
        
    elif brand == 'AMD':
        amd_brand_regex = 'Radeon (R\d )?Graphics'
        if re.search(amd_brand_regex, name) != None:
            return row.CPU_MODEL
        gpu_model = re.search(gpu_regex, name)
        if gpu_model != None:
            gpu_model = gpu_model.group(0)
            if 'XT' in name:
                gpu_model += ' XT'
            return gpu_model
        else:
            return 'Unknown'
        
    elif brand == 'Intel':
        gpuNameList = name.split()
        if 'Iris' in name or 'Irix' in name:
            if 'Intel' in gpuNameList:
                gpuNameList.remove('Intel')
            if 'Graphics' in gpuNameList:
                gpuNameList.remove("Graphics")
            if 'Irix' in gpuNameList:
                # Fix Irix type
                gpuNameList[gpuNameList.index('Irix')] = 'Iris'
            if 'X' in gpuNameList:
                # Fix X type
                gpuNameList[gpuNameList.index('X')] = 'Xe'
            return ' '.join(gpuNameList)
        elif 'UHD' in gpuNameList:
            # Search through  UHD json for corresponding UHD Graphic series
            for series in UHD_Data:
                if row.CPU_MODEL in UHD_Data[series]:
                    return series
            return 'UHD'
        else:
            return 'Unknown'
    
    elif brand == 'Apple':
        if 'GPU' in row.GRAPHICS:
            return row.GRAPHICS
        else:
            return row.CPU_MODEL     

    else:
        return 'Unknown'

laptop_modify['GPU_MODEL'] = laptop_modify.apply(extract_laptop_gpu, axis=1)
laptop_modify.head()
# Out:
#   LAPTOP_BRAND                                               NAME  \
# 0     Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1        Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2          MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3          MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4          MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
#
#               PRODUCTCODE  PRICE       PROCESSOR           MEMORY  \
# 0         A5 K1-AAU1130SB   1799   Ryzen 5-5600H       16GB , RAM
# 1      RZ09-0427NEA3-R3B1   2699  Ryzen 9-6900HX    16GB DDR5 RAM
# 2  Katana GF66 12UD-069AU   1549       i7-12700H  16GB , DDR4 RAM
# 3  Katana GF76 12UE-019AU   1899       i7-12700H       16GB , RAM
# 4   GF63 Thin 11SC-1095AU    999       i5-11400H        8GB , RAM
#
#                         GRAPHICS             STORAGE             DISPLAY  \
# 0  GeForce RTX 3060 Max-P Design  512GB M.2 PCIE SSD  15.6inch FHD 144Hz
# 1        GeForce RTX 3070 Ti 8GB    1TB M.2 PCIE SSD    14inch QHD 165Hz
# 2            GeForce RTX 3050 Ti    1TB M.2 PCIE SSD  15.6inch FHD 144Hz
# 3           GeForce RTX 3060 6GB    1TB M.2 PCIE SSD  17.3inch FHD 144Hz
# 4           GeForce GTX 1650 4GB  512GB M.2 PCIE SSD        15.6inch FHD
#
#   CPU_BRAND  CPU_MODEL GPU_BRAND GPU_MODEL
# 0       AMD      5600H    Nvidia      3060
# 1       AMD     6900HX    Nvidia   3070 Ti
# 2     Intel  i7-12700H    Nvidia   3050 Ti
# 3     Intel  i7-12700H    Nvidia      3060
# 4     Intel  i5-11400H    Nvidia      1650

# %%
# Show laptops with incorrect/missing data
laptop_modify[laptop_modify.GPU_MODEL == 'Unknown']
# Out:
#     LAPTOP_BRAND                                               NAME  \
# 8            MSI  MSI Katana GF66 12UC Black 15.6inch Core i7 RT...
# 41          ASUS  ASUS ROG Zephyrus Duo 16 Black 16inch Ryzen 9 ...
# 101     Gigabyte  Gigabyte G5 KD Black 15.6inch Core i5 RTX 3060...
# 118         ASUS  ASUS ROG Zephyrus Duo 16 Black 16inch Ryzen 9 ...
# 271         Asus  Asus ZenBook ProDuo 15 OLED 15.6in UHD Touch C...
# 283    Microsoft  Microsoft Surface Laptop 5 13.5inch Core i5 16...
# 287         ASUS  ASUS ZenBook Pro Duo 15 OLED 15.6 inch i7 16GB...
# 351         Asus  Asus Vivobook S 15.6 inch FHD OLED i5 8GB 256G...
# 521    Microsoft  Microsoft Surface Laptop 5 13.5inch Core i7 16...
# 522    Microsoft  Microsoft Surface Laptop 5 13.5inch Core i7 16...
# 648           HP  HP ZBook Fury 15 G8 15.6in FHD Core i9 32GB 51...
# 673           HP  HP ZBook Fury 15 G8 15.6in FHD Xeon 32GB 512GB...
#
#                 PRODUCTCODE  PRICE                 PROCESSOR  \
# 8    Katana GF66 12UC-656AU   1349                 i7-12650H
# 41           GX650RX-LB149W   5599            Ryzen 9-6900HX
# 101         G5 KD-52AU123SO   1799                 i5-11400H
# 118          GX650PY-NM056W   6999            Ryzen 9-7945HX
# 271          UX582ZM-H2009X   4399                i9-12900HK
# 283               R7B-00016   2399               256GB SSD ,
# 287          UX582ZM-KY012W   3799            Core i7-12700H
# 351          K3502ZA-L1367W   1499              Neutral Grey
# 521               RB1-00039   2699               256GB SSD ,
# 522               RBH-00041   2849               512GB SSD ,
# 648                 512C8PA   5099      Intel Core i9-11900H
# 673                 512C9PA   5799  Intel Xeon W-11955M vPro
#
#                                                 MEMORY  \
# 8                                            8GB , RAM
# 41                                     32GB , DDR5 RAM
# 101                                         16GB , RAM
# 118                                    64GB , DDR5 RAM
# 271                                           32GB RAM
# 283  13.5-inch PixelSense Gorilla Glass 3 Touch Dis...
# 287                                   16GB RAM onboard
# 351                                     Core i5-12500H
# 521  13.5-inch PixelSense Gorilla Glass 3 Touch Dis...
# 522  13.5-inch PixelSense Gorilla Glass 5 Touch Dis...
# 648                                         32GB RAM ,
# 673                                         32GB RAM ,
#
#                        GRAPHICS                  STORAGE  \
# 8                         GBLAN       15.6inch FHD 144Hz
# 41     ScreenPad Plus 14inch 4k         2TB M.2 PCIE SSD
# 101                       GBLAN       15.6inch FHD 144Hz
# 118    14inch ScreenPad Plus 4k         1TB M.2 PCIE SSD
# 271               ScreenPad Duo        1TB PCIe NVMe SSD
# 283                      HD Cam            Intel Iris Xe
# 287              ScreenPad Plus         1TB PCe Gen4 SSD
# 351          15.6 inch FHD OLED                    8GB ,
# 521                      HD Cam            Intel Iris Xe
# 522                      HD Cam            Intel Iris Xe
# 648           15.6 inch FHD IPS  512GB M.2 PCIe NVMe SSD
# 673  15.6 inch FHD IPS 400 nits       512GB PCIe M.2 SSD
#
#                               DISPLAY CPU_BRAND     CPU_MODEL GPU_BRAND  \
# 8                GeForce RTX 3050 4GB     Intel     i7-12650H   Unknown
# 41   16inch UHD+ 120Hz and FHD+ 240Hz       AMD        6900HX   Unknown
# 101     GeForce RTX 3060 Max-P Design     Intel     i5-11400H   Unknown
# 118                 16inch QHD+ 240Hz       AMD        7945HX   Unknown
# 271       15.6 inch 4K UHD OLED Touch     Intel    i9-12900HK   Unknown
# 283                   WIFI 6 + BT 5.1   Unknown   256GB SSD ,   Unknown
# 287          15.6 inch FHD OLED Touch     Intel     i7-12700H   Unknown
# 351                     256GB M.2 SSD   Unknown  Neutral Grey   Unknown
# 521                   WIFI 6 + BT 5.1   Unknown   256GB SSD ,   Unknown
# 522                   WIFI 6 + BT 5.1   Unknown   512GB SSD ,   Unknown
# 648                      1TB SATA HDD     Intel     i9-11900H   Unknown
# 673                      1TB SATA HDD     Intel      W-11955M   Unknown
#
#     GPU_MODEL
# 8     Unknown
# 41    Unknown
# 101   Unknown
# 118   Unknown
# 271   Unknown
# 283   Unknown
# 287   Unknown
# 351   Unknown
# 521   Unknown
# 522   Unknown
# 648   Unknown
# 673   Unknown

# %%
# Remove Laptops with incorrect/missing data
laptop_modify.drop(laptop_modify[laptop_modify.GPU_MODEL == 'Unknown'].index, inplace=True)

# %%
# Clean up Memory Column and create RAM column
laptop_modify.MEMORY = laptop_modify.MEMORY.map(lambda s: s.replace(',', '').strip())
laptop_modify['RAM'] = laptop_modify.MEMORY.str.extract(r'(^\d+)')
laptop_modify.RAM = laptop_modify.RAM.astype(int)
laptop_modify.head()
# Out:
#   LAPTOP_BRAND                                               NAME  \
# 0     Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1        Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2          MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3          MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4          MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
#
#               PRODUCTCODE  PRICE       PROCESSOR          MEMORY  \
# 0         A5 K1-AAU1130SB   1799   Ryzen 5-5600H       16GB  RAM
# 1      RZ09-0427NEA3-R3B1   2699  Ryzen 9-6900HX   16GB DDR5 RAM
# 2  Katana GF66 12UD-069AU   1549       i7-12700H  16GB  DDR4 RAM
# 3  Katana GF76 12UE-019AU   1899       i7-12700H       16GB  RAM
# 4   GF63 Thin 11SC-1095AU    999       i5-11400H        8GB  RAM
#
#                         GRAPHICS             STORAGE             DISPLAY  \
# 0  GeForce RTX 3060 Max-P Design  512GB M.2 PCIE SSD  15.6inch FHD 144Hz
# 1        GeForce RTX 3070 Ti 8GB    1TB M.2 PCIE SSD    14inch QHD 165Hz
# 2            GeForce RTX 3050 Ti    1TB M.2 PCIE SSD  15.6inch FHD 144Hz
# 3           GeForce RTX 3060 6GB    1TB M.2 PCIE SSD  17.3inch FHD 144Hz
# 4           GeForce GTX 1650 4GB  512GB M.2 PCIE SSD        15.6inch FHD
#
#   CPU_BRAND  CPU_MODEL GPU_BRAND GPU_MODEL  RAM
# 0       AMD      5600H    Nvidia      3060   16
# 1       AMD     6900HX    Nvidia   3070 Ti   16
# 2     Intel  i7-12700H    Nvidia   3050 Ti   16
# 3     Intel  i7-12700H    Nvidia      3060   16
# 4     Intel  i5-11400H    Nvidia      1650    8

# %%
# Clean up Storage column and create STORAGE_SIZE column
laptop_modify.STORAGE = laptop_modify.STORAGE.map(lambda s: s.replace(',', '').strip())

def calc_storage(row):
    totalStorage = 0
    hd_regex = r'(\d+)\s?(GB|TB)'
    storage = row.STORAGE
    storageList = storage.split('+')
    storageList = [item.strip() for item in storageList]
    for hardDrive in storageList:
        hdStorage = re.search(hd_regex, hardDrive)
        if 'TB' in hdStorage.group(0):
            hdStorage = int(hdStorage.group(1))
            hdStorage = hdStorage*1000
        else:
            hdStorage = int(hdStorage.group(1))
        totalStorage += int(hdStorage)

    return totalStorage

laptop_modify['STORAGE_SIZE'] = laptop_modify.apply(calc_storage, axis=1)
laptop_modify
# Out:
#     LAPTOP_BRAND                                               NAME  \
# 0       Gigabyte  Gigabyte A5 K1 Black 15.6inch Ryzen 5 RTX 3060...
# 1          Razer  Razer Blade 14 Black 14inch Ryzen 9 RTX 3070 T...
# 2            MSI  MSI Katana GF66 12UD 15.6inch Core i7 RTX 3050...
# 3            MSI  MSI Katana GF76 12UE Black 17.3inch Core i7 RT...
# 4            MSI  MSI GF63 Thin 11SC Black 15.6inch Core i5 GTX ...
# ..           ...                                                ...
# 683       Lenovo  Lenovo ThinkPad P15v G3 15.6 inch FHD i7 16GB ...
# 684          MSI  MSI Creator M16 A12UC 16 inch i7 RTX3050 Win11...
# 685          MSI  MSI CreatorPro Z17 A12UMST 17" Core i7 32GB 1T...
# 686          MSI  MSI CreatorPro X17HX A13VKS 17.3inch Core i9 6...
# 687          MSI  MSI CreatorPro Z17 HX Studio A13VKT 17" i7 64G...
#
#                              PRODUCTCODE  PRICE        PROCESSOR  \
# 0                        A5 K1-AAU1130SB   1799    Ryzen 5-5600H
# 1                     RZ09-0427NEA3-R3B1   2699   Ryzen 9-6900HX
# 2                 Katana GF66 12UD-069AU   1549        i7-12700H
# 3                 Katana GF76 12UE-019AU   1899        i7-12700H
# 4                  GF63 Thin 11SC-1095AU    999        i5-11400H
# ..                                   ...    ...              ...
# 683                           21D80022AU   2699   Core i7-12700H
# 684              Creator M16 A12UC-237AU   2399   Core i7-12700H
# 685         CreatorPro Z17 A12UMST-218AU   6599   Core i7-12700H
# 686        CreatorPro X17HX A13VKS-204AU   9599  Core i9-13980HX
# 687  CreatorPro Z17HXStudio A13VKT-052AU   7999  Core i9-13950HX
#
#              MEMORY                       GRAPHICS  \
# 0         16GB  RAM  GeForce RTX 3060 Max-P Design
# 1     16GB DDR5 RAM        GeForce RTX 3070 Ti 8GB
# 2    16GB  DDR4 RAM            GeForce RTX 3050 Ti
# 3         16GB  RAM           GeForce RTX 3060 6GB
# 4          8GB  RAM           GeForce GTX 1650 4GB
# ..              ...                            ...
# 683   16GB RAM DDR5                Nvidia T600 4GB
# 684        16GB RAM                    RTX3050 4GB
# 685   32GB DDR5 RAM                 RTX A5500 16GB
# 686   64GB DDR5 RAM                  RTX 3500 12GB
# 687   64GB DDR5 RAM                   RTX 3000 8GB
#
#                          STORAGE                        DISPLAY CPU_BRAND  \
# 0             512GB M.2 PCIE SSD             15.6inch FHD 144Hz       AMD
# 1               1TB M.2 PCIE SSD               14inch QHD 165Hz       AMD
# 2               1TB M.2 PCIE SSD             15.6inch FHD 144Hz     Intel
# 3               1TB M.2 PCIE SSD             17.3inch FHD 144Hz     Intel
# 4             512GB M.2 PCIE SSD                   15.6inch FHD     Intel
# ..                           ...                            ...       ...
# 683                512GB M.2 SSD              15.6 inch FHD IPS     Intel
# 684                    512GB SSD              16 inch QHD+ 60Hz     Intel
# 685   1TB M.2 NVMe PCIe Gen4 SSD              17inch QHD+ 165Hz     Intel
# 686  4TB  M.2 NVMe PCIe Gen4 SSD             17.3inch UHD 144Hz     Intel
# 687   2TB M.2 NVMe PCIe Gen4 SSD  17inch QHD+ 165Hz Touchscreen     Intel
#
#       CPU_MODEL GPU_BRAND GPU_MODEL  RAM  STORAGE_SIZE
# 0         5600H    Nvidia      3060   16           512
# 1        6900HX    Nvidia   3070 Ti   16          1000
# 2     i7-12700H    Nvidia   3050 Ti   16          1000
# 3     i7-12700H    Nvidia      3060   16          1000
# 4     i5-11400H    Nvidia      1650    8           512
# ..          ...       ...       ...  ...           ...
# 683   i7-12700H    Nvidia      T600   16           512
# 684   i7-12700H       AMD   RTX3050   16           512
# 685   i7-12700H       AMD     A5500   32          1000
# 686  i9-13980HX       AMD      3500   64          4000
# 687  i9-13950HX       AMD      3000   64          2000
#
# [676 rows x 15 columns]

# %%
print(laptop_modify.DISPLAY.to_string())
# Out:
# 0                                     15.6inch FHD 144Hz
# 1                                       14inch QHD 165Hz
# 2                                     15.6inch FHD 144Hz
# 3                                     17.3inch FHD 144Hz
# 4                                           15.6inch FHD
# 5                                     15.6inch FHD 144Hz
# 6                                     15.6inch FHD 144Hz
# 7                                     17.3inch FHD 144Hz
# 9                                     17.3inch FHD 144Hz
# 10                                    17.3inch FHD 144Hz
# 11                                    15.6inch FHD 144Hz
# 12                                    17.3inch QHD 240Hz
# 13                                    15.6inch FHD 240Hz
# 14                                   15.6inch WQHD 165Hz
# 15                                  15.6" OLED QHD 240Hz
# 16                                    17.3inch FHD 144Hz
# 17                                    15.6inch FHD 144Hz
# 18                                    15.6inch FHD 144Hz
# 19                                    15.6inch FHD 144Hz
# 20                                    17.3inch FHD 144Hz
# 21                                    15.6inch FHD 144Hz
# 22                                    17.3inch QHD 240Hz
# 23                            17.3inch UHD MiniLED 120Hz
# 24                                    15.6inch QHD 165Hz
# 25                                     15.6inch UHD OLED
# 26               14inch WUXGA 144Hz AniMe Matrix Version
# 27                                    17.3inch FHD 144Hz
# 28                                    15.6inch FHD 144Hz
# 29                                      16inch UHD+ OLED
# 30                                     16inch QHD+ 240Hz
# 31                               15.6inch OLED QHD 240Hz
# 32                                    18-inch QHD+ 240Hz
# 33                                    15.6inch FHD 300Hz
# 34                                    17.3inch QHD 240Hz
# 35                                    15.6inch QHD 165Hz
# 36                                    16-inch QHD+ 240Hz
# 37                                    17.3inch QHD 165Hz
# 38                                    15.6inch FHD 300Hz
# 39                                    16inch WUXGA 165Hz
# 40                                     15.6inch UHD OLED
# 42                                     17.3inch 4k 144Hz
# 43                                    17.3inch QHD 240Hz
# 44                                     16inch QHD+ 165Hz
# 45                                    15.6inch QHD 165Hz
# 46                                     18inch QHD+ 240Hz
# 47                                    17.3inch QHD 165Hz
# 48                                     16inch FHD+ 165Hz
# 49                                    17.3inch UHD 144Hz
# 50                                    17.3inch FHD 144Hz
# 51                                16inch WQXGA IPS 240Hz
# 52                                    17.3inch FHD 360Hz
# 53                                     18inch QHD+ 240Hz
# 54                                    15.6inch QHD 165Hz
# 55                                    15.6inch QHD 165Hz
# 56                                    15.6inch FHD 300Hz
# 57                                    15.6inch FHD 144Hz
# 58                                    17.3inch FHD 144Hz
# 59                                    16inch WQXGA 240Hz
# 60                                    15.6inch FHD 144Hz
# 61                                    15.6inch FHD 144Hz
# 62                                   15.6-inch FHD 144Hz
# 63                                    17.3inch QHD 165Hz
# 64                                    15.6inch QHD 240Hz
# 65                                      16inch UHD+ OLED
# 66                                    17.3inch QHD 240Hz
# 67                                    15.6inch QHD 165Hz
# 68                                    15.6inch FHD 144Hz
# 69                                    17.3inch FHD 144Hz
# 70                                    15.6inch FHD 144Hz
# 71                                    15.6inch FHD 144Hz
# 72                                    16-inch QHD+ 240Hz
# 73                                     18inch QHD+ 240Hz
# 74                                    15.6inch FHD 144Hz
# 75                                    17.3inch FHD 360Hz
# 76                                    15.6inch FHD 300Hz
# 77                                   17.3inch WQHD 240Hz
# 78                                    16inch WQXGA 240Hz
# 79                                    17.3inch FHD 144Hz
# 80                                    17.3inch FHD 144Hz
# 81                                     16inch QHD+ 240Hz
# 82                                   17.3inch WQHD 240Hz
# 83                                    15.6inch QHD 165Hz
# 84                                    17inch WQXGA 240Hz
# 85                                15.6inch QHD IPS 165Hz
# 86                                     17.3inch 4k 144Hz
# 87                                     17.3inch 4k 144Hz
# 88                                   15.6-inch FHD 144Hz
# 89                                    16-inch QHD+ 240Hz
# 90                                    17.3inch QHD 240Hz
# 91                                    17.3inch QHD 240Hz
# 92                                     18inch QHD+ 240Hz
# 93                                     18inch QHD+ 240Hz
# 94                                      16inch UHD+ OLED
# 95                                           14inch QHD+
# 96                                    17.3inch FHD 360Hz
# 97                                    17.3inch QHD 165Hz
# 98                                    17.3inch QHD 165Hz
# 99                                    15.6inch QHD 165Hz
# 100                                   17.3inch QHD 165Hz
# 102                    13.4inch WUXGA 120Hz Touch Screen
# 103                                   15.6inch FHD 144Hz
# 104                                   15.6inch QHD 165Hz
# 105                                   15.6inch FHD 144Hz
# 106                               16.1inch QHD 165Hz IPS
# 107                               16.1inch FHD 144Hz IPS
# 108                                   17inch WQXGA 240Hz
# 109                                   17.3inch FHD 144Hz
# 110                                    16inch QHD+ 240Hz
# 111                                    16inch QHD+ 240Hz
# 112                                   15.6inch FHD 144Hz
# 113                                     17inch QHD 240Hz
# 114                                   17.3inch FHD 144Hz
# 115                                   17.3inch FHD 144Hz
# 116                                    16-inch FHD 165Hz
# 117                                     16inch OLED UHD+
# 119                                   15.6inch FHD 144Hz
# 120                                 17.3inch WQXGA 240Hz
# 121                                   15.6inch FHD 144Hz
# 122                                   15.6inch FHD 240Hz
# 123                                   15.6inch FHD 144Hz
# 124                                   15.6inch FHD 144Hz
# 125                                   17.3inch FHD 120Hz
# 126                                   15.6inch FHD 120Hz
# 127                                     15.6inch FHD IPS
# 128                                    15.6inch OLED UHD
# 129                                   15.6inch FHD 144Hz
# 130                               17.3inch QHD 165Hz IPS
# 131                               17.3inch QHD 165Hz IPS
# 132                               16.1inch QHD 165Hz IPS
# 133                               16.1inch QHD 165Hz IPS
# 134                                    17.3inch 4k 144Hz
# 135                                   15.6inch FHD 144Hz
# 136                                   15.6inch FHD 144Hz
# 137                                      16inch 4k 120Hz
# 138                                     16inch QHD 240Hz
# 139                                     16inch QHD 240Hz
# 140                                     17inch QHD 240Hz
# 141                                    17.3inch 4K 120Hz
# 142                                      16inch 4K 120Hz
# 143                                     16inch QHD 240Hz
# 144                              15.6inch OLED QHD 240Hz
# 145                                   17.3inch QHD 240Hz
# 146                                   17.3inch QHD 240Hz
# 147                              15.6inch OLED QHD 240Hz
# 148                                   15.6inch FHD 144Hz
# 149                                  15.6-inch FHD 144Hz
# 150                                   17.3inch QHD 240Hz
# 151                                   17.3inch QHD 240Hz
# 152                                   17.3inch FHD 144Hz
# 153                                   15.6inch QHD 165Hz
# 154                  16inch UHD+ 240Hz and FHD+ Mini LED
# 155                                    16inch QHD+ 240Hz
# 156                           16inch UHD+ 240Hz and FHD+
# 157                                     16inch OLED UHD+
# 158                                   15.6inch QHD 165Hz
# 159                                   15.6inch FHD 144Hz
# 160                                   17.3inch QHD 240Hz
# 161                                 16.1inch WQXGA 240Hz
# 162                                 16.1inch WQXGA 240Hz
# 163                                   16inch WUXGA 165Hz
# 164                                   15.6inch FHD 144Hz
# 165                                   15.6inch FHD 144Hz
# 166                                   15.6inch FHD 144Hz
# 167                                   15.6inch FHD 144Hz
# 168                                    15.6 inch FHD IPS
# 169                                    15.6 inch FHD IPS
# 170                              15.6 inch FHD IPS Touch
# 171                                      14 inch FHD IPS
# 172                                    15.6 inch FHD IPS
# 173                                    15.6 inch FHD IPS
# 174                                          14 inch FHD
# 175                                    15.6 inch FHD IPS
# 176                                  14.0 inch WUXGA IPS
# 177                                      14 inch FHD IPS
# 178                              14.0 inch FHD IPS Touch
# 179                                        15.6 inch FHD
# 180                       15.6 inch FHD Touch Screen IPS
# 181                                  14.0 inch WUXGA IPS
# 182                                      14 inch FHD IPS
# 183                                      14 inch FHD IPS
# 184                                      14 inch FHD IPS
# 185                                15.6 inch FHD Display
# 186                                 14.0 inch HD Display
# 187                                        14.0 inch FHD
# 188                                    15.6 inch FHD IPS
# 189                                 15.6 inch HD Display
# 190                            14.5-inch 2.8K OLED 120Hz
# 191                                  14 inch FHD Display
# 192                                        15.6-inch FHD
# 193                                      14 inch FHD IPS
# 194                            13.5 inch 3K2K OLED Touch
# 195                            15.6 inch 3.2K OLED 120Hz
# 196                                        14.0 inch FHD
# 197                            15.6 inch FHD IPS Display
# 198                                15.6 inch FHD Display
# 199                              15.6 inch FHD IPS Touch
# 200                                 15.6 inch HD Display
# 201                            14 inch 2.8K OLED Display
# 202                                    15.6 inch FHD IPS
# 203                              15.6 inch FHD IPS Touch
# 204                                      14 inch FHD IPS
# 205                                    15.6 inch FHD IPS
# 206                                    15.6 inch FHD IPS
# 207                                        14-inch WQXGA
# 208                           13.5 inch PixelSense Touch
# 209                            15.6" Touch FHD 1080p IPS
# 210                           15.6 inch FHD OLED PANTONE
# 211                                       14inch FHD IPS
# 212                                 14.0 inch HD Display
# 213                                        17.3 inch HD+
# 214                                      14 inch FHD IPS
# 215                           15.6 inch FHD OLED PANTONE
# 216                                     15.6inch FHD IPS
# 217                                      14 inch FHD IPS
# 218                                      14 inch FHD IPS
# 219                                      14 inch FHD IPS
# 220                              14 inch WUXGA IPS Touch
# 221                                        15.6-inch FHD
# 222                                        15.6 inch FHD
# 223                            13.3 inch 2560 x 1600 IPS
# 224                                  14.0 inch WUXGA IPS
# 225                                    15.6 inch FHD IPS
# 226                                14 inch WQXGA 400nits
# 227                            14.0 inch WUXGA IPS Touch
# 228                                      14 inch FHD IPS
# 229                                      14 inch FHD IPS
# 230                                     15.6inch FHD IPS
# 231                            13.3 inch 2560 x 1600 IPS
# 232                                 15.6 inch HD Display
# 233                                 14.0 inch HD Display
# 234                    14.0 inch FHD Privacy IPS Display
# 235                               14 inch QHD+ IPS Touch
# 236                                  14.0 inch FHD Touch
# 237                                  15.6 inch WUXGA IPS
# 238                                      14 inch FHD IPS
# 239              14.2-inch 3024 x 1964 Liquid Retina XDR
# 240                                        15.6-inch FHD
# 241                            14.0 inch WUXGA IPS Touch
# 242                            14.5-inch 2.8K OLED 120Hz
# 243                      14.0 inch WUXGA IPS Touchscreen
# 244              13.5 inch PixelSense Display 10pt Touch
# 245                   13.3 inch FHD 300nits Touch Screen
# 246                                 14.0 inch HD Display
# 247                              14.0 inch FHD IPS Touch
# 248                                  14.0 inch WUXGA IPS
# 249                                    15.6 inch FHD IPS
# 250                                      14 inch FHD IPS
# 251                                        14.0 inch FHD
# 252                                      14" FHD Display
# 253                                     17inch WQXGA IPS
# 254                                     16inch WQXGA IPS
# 255                                      14 inch FHD IPS
# 256                                    14.0 inch FHD IPS
# 257                16-inch 3456 x 2234 Liquid Retina XDR
# 258                16-inch 3456 x 2234 Liquid Retina XDR
# 259                                    15.6 inch FHD IPS
# 260                                  16.0 inch WUXGA IPS
# 261                                          14" FHD WVA
# 262                                         15.6inch FHD
# 263                                        15.6-inch FHD
# 264                                      14 inch FHD IPS
# 265                                         13.3 inch HD
# 266                           13.5 inch PixelSense Touch
# 267                           13.5 inch PixelSense Touch
# 268                14-inch 3024 x 1964 Liquid Retina XDR
# 269                14-inch 3024 x 1964 Liquid Retina XDR
# 270                                        14.0 inch FHD
# 272                                         13.3 inch HD
# 273                                 15.6 inch HD Display
# 274                                 14.0 inch HD Display
# 275                                 14.0 inch HD Display
# 276                            14.0 inch FHD IPS Display
# 277                                 14.0 inch HD Display
# 278                      13.6 inch Liquid Retina Display
# 279                                  15.6inch FHD OLED ,
# 280                                13.3 inch FHD Display
# 281                                    14.0 inch FHD WVA
# 282                                      14 inch FHD IPS
# 284                            14.0 inch WUXGA IPS Touch
# 285                                  15.6 inch WUXGA IPS
# 286                                  13.3 inch WUXGA IPS
# 288      13.5-inch PixelSense Touch with Gorilla Glass 5
# 289                                     17inch WQXGA IPS
# 290                                      14.0-inch WQXGA
# 291                            14.5-inch 2.8K OLED 120Hz
# 292             14.5-inch WQXGA+ OLED 120Hz Touch Screen
# 293                                          14-inch FHD
# 294                                    15.6-inch FHD IPS
# 295              15.0 inch PixelSense Display 10pt Touch
# 296              15.0 inch PixelSense Display 10pt Touch
# 297                            13.3 inch 2560 x 1600 IPS
# 298                            13.3 inch 2560 x 1600 IPS
# 299                              13.3 inch 2560x1600 IPS
# 300                                  13.3 inch FHD Touch
# 301                                    17.3 inch FHD IPS
# 302                           15.0 inch PixelSense Touch
# 303                           15.0 inch PixelSense Touch
# 304                           15.0 inch PixelSense Touch
# 305                           15.0 inch PixelSense Touch
# 306                           15.0 inch PixelSense Touch
# 307                           13.5 inch PixelSense Touch
# 308                           13.5 inch PixelSense Touch
# 309                           13.5 inch PixelSense Touch
# 310                           13.5 inch PixelSense Touch
# 311                           13.5 inch PixelSense Touch
# 312                           13.5 inch PixelSense Touch
# 313                                    14.0 inch FHD IPS
# 314                           14.0 inch IPS FHD 400 nits
# 315                    13.3 inch OLED FHD Touch 400 nits
# 316                    13.3 inch UHD OLED 400 nits Touch
# 317                16-inch 3456 x 2234 Liquid Retina XDR
# 318                16-inch 3456 x 2234 Liquid Retina XDR
# 319                16-inch 3456 x 2234 Liquid Retina XDR
# 320                16-inch 3456 x 2234 Liquid Retina XDR
# 321                16-inch 3456 x 2234 Liquid Retina XDR
# 322                14-inch 3024 x 1964 Liquid Retina XDR
# 323                14-inch 3024 x 1964 Liquid Retina XDR
# 324                                    14.0 inch FHD IPS
# 325                                      14 inch FHD IPS
# 326                     14.0 inch OLED 2.8K Touch Screen
# 327                          14 inch FHD 250nits Display
# 328                                 15.6 inch HD Display
# 329               15.6 inch FHD Touch Screen IPS Display
# 330                                         15.6 inch HD
# 331                                 15.6 inch HD Display
# 332                                 15.6 inch HD Display
# 333                                 15.6 inch HD Display
# 334               15.6 inch FHD Touch Screen IPS Display
# 335                                 15.6 inch HD Display
# 336                                    15.6 inch FHD IPS
# 337                                 14.0 inch HD Display
# 338                            13.3 inch FHD Privacy IPS
# 339                    14.0 inch FHD Privacy IPS Display
# 340                                 14.0 inch HD Display
# 341                              13.3 inch 2560x1600 IPS
# 342                              13.3 inch 2560x1600 IPS
# 343                              13.3 inch 2560x1600 IPS
# 344                              13.3 inch 2560x1600 IPS
# 345                                  13.3 inch FHD Touch
# 346                      13.6 inch Liquid Retina Display
# 347                              15.6 inch FHD IPS Touch
# 348                     14.4 inch PixelSense Touch 120Hz
# 349                     13.5 inch WUXGA IPS Touch Screen
# 350                                  13.5 inch WUXGA IPS
# 352                             14.0 inch WUXGA IPS Pvcy
# 353                                  14.0 inch WUXGA IPS
# 354                                  14.0 inch WUXGA IPS
# 355                                  16.0 inch WUXGA IPS
# 356                                  16.0 inch WUXGA IPS
# 357                                         17.3inch HD+
# 358                         16inch 4K OLED Touchscreen ,
# 359                           14.4 inch PixelSense Touch
# 360                            15.6 inch FHD IPS Display
# 361                            15.6 inch FHD IPS Display
# 362                                    15.6 inch FHD IPS
# 363                   13.5-inch PixelSense Touch Display
# 364                            13.5 inch WUXGA IPS Touch
# 365                                    15.6 inch FHD WVA
# 366                                16 inch 3K+ IPS Touch
# 367                              16 inch UHD+ OLED Touch
# 368                                    15.6 inch FHD IPS
# 369                                  14.0 inch WUXGA IPS
# 370                            13.3 inch WUXGA IPS Touch
# 371                           15.0 inch PixelSense Touch
# 372    13.5-inch PixelSense Gorilla Glass 5 Touch Dis...
# 373     15-inch PixelSense Gorilla Glass 5 Touch Display
# 374                                    15.6 inch FHD IPS
# 375                                         15.6inch FHD
# 376                                         15.6inch FHD
# 377                                         15.6inch FHD
# 378                              14.0 inch FHD IPS Touch
# 379                                          14inch QHD+
# 380                                          14inch QHD+
# 381                                         13.3inch FHD
# 382                                         13.3inch FHD
# 383                                     16inch WQXGA IPS
# 384              16.2-inch 3456 x 2234 Liquid Retina XDR
# 385                                      14 inch FHD IPS
# 386             13.3 inch WUXGA Brightview Privacy Touch
# 387                         14-inch QHD+ IPS Touch Panel
# 388                        13.3" WUXGA IPS Touch Display
# 389                                       14inch FHD IPS
# 390                                         15.6 inch HD
# 391                                    13.3 inch FHD IPS
# 392                                        15.6-inch FHD
# 393              13.5 inch PixelSense Display 10pt Touch
# 394              13.5 inch PixelSense Display 10pt Touch
# 395              15.0 inch PixelSense Display 10pt Touch
# 396              15.0 inch PixelSense Display 10pt Touch
# 397                           15.0 inch PixelSense Touch
# 398                           13.5 inch PixelSense Touch
# 399                           15.0 inch PixelSense Touch
# 400                           15.0 inch PixelSense Touch
# 401                           15.0 inch PixelSense Touch
# 402                           15.0 inch PixelSense Touch
# 403                           13.5 inch PixelSense Touch
# 404                           13.5 inch PixelSense Touch
# 405                           13.5 inch PixelSense Touch
# 406                           13.5 inch PixelSense Touch
# 407                           13.5 inch PixelSense Touch
# 408                           13.5 inch PixelSense Touch
# 409                           13.5 inch PixelSense Touch
# 410                           13.5 inch PixelSense Touch
# 411                                    15.6 inch FHD WVA
# 412                                    14.0 inch FHD IPS
# 413                              14.0 inch FHD IPS Touch
# 414                              15.6 inch IPS FHD Touch
# 415                                    14.0 inch FHD IPS
# 416                                    15.6 inch FHD IPS
# 417                              13.3 inch FHD IPS Touch
# 418                      13.3 inch FHD+ WVA Touch Screen
# 419                            14.0 inch FHD IPS 400nits
# 420                            14.0 inch FHD IPS 400nits
# 421                16-inch 3456 x 2234 Liquid Retina XDR
# 422                14 inch 3024 x 1964 Liquid Retina XDR
# 423                       13.3 inch FHD IPS Touch Screen
# 424                                 15.6 inch HD Display
# 425               15.6 inch FHD Touch Screen IPS Display
# 426                                 15.6 inch HD Display
# 427               15.6 inch FHD Touch Screen IPS Display
# 428                                 15.6 inch HD Display
# 429                                 15.6 inch HD Display
# 430                                 15.6 inch HD Display
# 431                                 15.6 inch HD Display
# 432                                 15.6 inch HD Display
# 433                                 15.6 inch HD Display
# 434                                 15.6 inch HD Display
# 435                                 15.6 inch HD Display
# 436               15.6 inch FHD Touch Screen IPS Display
# 437               15.6 inch FHD Touch Screen IPS Display
# 438               15.6 inch FHD Touch Screen IPS Display
# 439                                    15.6 inch FHD IPS
# 440                                 14.0 inch HD Display
# 441                                 14.0 inch HD Display
# 442                                 14.0 inch HD Display
# 443                                 14.0 inch HD Display
# 444                                 14.0 inch HD Display
# 445                                 14.0 inch HD Display
# 446                                 14.0 inch HD Display
# 447                                 14.0 inch HD Display
# 448                                 14.0 inch HD Display
# 449                                 14.0 inch HD Display
# 450                     14.0 inch WUXGA IPS Touch Screen
# 451                     14.0 inch WUXGA IPS Touch Screen
# 452                               14 inch QHD+ IPS Touch
# 453                               14 inch QHD+ IPS Touch
# 454                      13.6 inch Liquid Retina Display
# 455                      13.6 inch Liquid Retina Display
# 456                      13.6 inch Liquid Retina Display
# 457                      13.6 inch Liquid Retina Display
# 458                      13.6 inch Liquid Retina Display
# 459                      13.6 inch Liquid Retina Display
# 460                      13.6 inch Liquid Retina Display
# 461                                  13.5 inch WUXGA IPS
# 462                                  13.5 inch WUXGA IPS
# 463                                  13.5 inch WUXGA IPS
# 464                                  13.5 inch WUXGA IPS
# 465                                  13.5 inch WUXGA IPS
# 466                                16 inch 4K OLED 16:10
# 467                               14.0 inch WUXGA IPS TS
# 468                                  14.0 inch WUXGA IPS
# 469                                  14.0 inch WUXGA IPS
# 470                                  14.0 inch WUXGA IPS
# 471                                  14.0 inch WUXGA IPS
# 472                                  14.0 inch WUXGA IPS
# 473                               16.0 inch WUXGA IPS TS
# 474                                  16.0 inch WUXGA IPS
# 475                                  16.0 inch WUXGA IPS
# 476                                  16.0 inch WUXGA IPS
# 477                                  16.0 inch WUXGA IPS
# 478                                  16.0 inch WUXGA IPS
# 479                                  16.0 inch WUXGA IPS
# 480                                  16.0 inch WUXGA IPS
# 481                             16.0 inch WUXGA IPS Pvcy
# 482                              13.5 inch QHD IPS Touch
# 483                         17.3inch FOLED Touchscreen ,
# 484                                    13.3 inch FHD IPS
# 485                           14.4 inch PixelSense Touch
# 486                           14.4 inch PixelSense Touch
# 487                           14.4 inch PixelSense Touch
# 488                           14.4 inch PixelSense Touch
# 489                           14.4 inch PixelSense Touch
# 490                            15.6 inch FHD IPS Display
# 491                            15.6 inch FHD IPS Display
# 492                                    15.6 inch FHD IPS
# 493                   13.5-inch PixelSense Touch Display
# 494                   13.5-inch PixelSense Touch Display
# 495                   13.5-inch PixelSense Touch Display
# 496                   13.5-inch PixelSense Touch Display
# 497                   13.5-inch PixelSense Touch Display
# 498                   13.5-inch PixelSense Touch Display
# 499                   13.5-inch PixelSense Touch Display
# 500                   13.5-inch PixelSense Touch Display
# 501                   13.5-inch PixelSense Touch Display
# 502                   13.5-inch PixelSense Touch Display
# 503                   13.5-inch PixelSense Touch Display
# 504                   13.5-inch PixelSense Touch Display
# 505                   13.5-inch PixelSense Touch Display
# 506                   13.5-inch PixelSense Touch Display
# 507                   13.5-inch PixelSense Touch Display
# 508                              14.0 inch FHD IPS Touch
# 509                          14 inch FHD High Brightness
# 510                    14 inch FHD Touch High Brightness
# 511                                16 inch 4K OLED 16:10
# 512                           15.0 inch PixelSense Touch
# 513                           15.0 inch PixelSense Touch
# 514                           15.0 inch PixelSense Touch
# 515                           15.0 inch PixelSense Touch
# 516                                     14 inch FHD+ IPS
# 517                                     14 inch FHD+ IPS
# 518    13.5-inch PixelSense Gorilla Glass 5 Touch Dis...
# 519    13.5-inch PixelSense Gorilla Glass 3 Touch Dis...
# 520    13.5-inch PixelSense Gorilla Glass 5 Touch Dis...
# 523    13.5-inch PixelSense Gorilla Glass 3 Touch Dis...
# 524     15-inch PixelSense Gorilla Glass 5 Touch Display
# 525     15-inch PixelSense Gorilla Glass 5 Touch Display
# 526     15-inch PixelSense Gorilla Glass 5 Touch Display
# 527     15-inch PixelSense Gorilla Glass 5 Touch Display
# 528                       14.0 inch WUXGA IPS Touch Pvcy
# 529                                    17.3 inch FHD IPS
# 530                                      14 inch FHD IPS
# 531                                      14 inch FHD IPS
# 532                                    16 inch WUXGA IPS
# 533                                    14 inch 2.8K OLED
# 534                                        14.0 inch FHD
# 535                                    15.6 inch FHD IPS
# 536                                      14 inch FHD IPS
# 537                16-inch 3456 x 2234 Liquid Retina XDR
# 538      13.5-inch PixelSense Touch with Gorilla Glass 5
# 539      13.5-inch PixelSense Touch with Gorilla Glass 5
# 540      13.5-inch PixelSense Touch with Gorilla Glass 5
# 541      13.5-inch PixelSense Touch with Gorilla Glass 5
# 542      13.5-inch PixelSense Touch with Gorilla Glass 5
# 543                                      14" FHD Display
# 544                                         14.0inch FHD
# 545                                           14inch FHD
# 546                                           14inch FHD
# 547                              14.0 inch FHD IPS Touch
# 548                                    16inch QHD+ 165Hz
# 549                                   13.4inch FHD 120Hz
# 550                                   13.4inch FHD 120Hz
# 551                                           14inch FHD
# 552                                         13.3inch FHD
# 553                                       14inch FHD IPS
# 554                                       14inch FHD IPS
# 555              16.2-inch 3456 x 2234 Liquid Retina XDR
# 556              16.2-inch 3456 x 2234 Liquid Retina XDR
# 557              16.2-inch 3456 x 2234 Liquid Retina XDR
# 558              16.2-inch 3456 x 2234 Liquid Retina XDR
# 559              16.2-inch 3456 x 2234 Liquid Retina XDR
# 560              14.2-inch 3024 x 1964 Liquid Retina XDR
# 561              14.2-inch 3024 x 1964 Liquid Retina XDR
# 562              14.2-inch 3024 x 1964 Liquid Retina XDR
# 563              14.2-inch 3024 x 1964 Liquid Retina XDR
# 564              14.2-inch 3024 x 1964 Liquid Retina XDR
# 565                        14inch WUXGA IPS Touch Screen
# 566                                        15.6-inch FHD
# 567                              16-inch 3.2K OLED 120Hz
# 568                            14.5-inch 2.8K OLED 120Hz
# 569             13.3 inch WUXGA Brightview Privacy Touch
# 570                                      14 inch FHD IPS
# 571                                      14 inch FHD IPS
# 572                                      14 inch FHD IPS
# 573                                      14 inch FHD IPS
# 574                             14.0inch FHD Touchscreen
# 575                                    15.6 inch FHD IPS
# 576                                    15.6 inch FHD IPS
# 577                                    15.6 inch FHD IPS
# 578                                    15.6 inch FHD IPS
# 579                                  13.3 inch WUXGA IPS
# 580                            13.4-inch FHD Touch Panel
# 581                            13.4-inch FHD Touch Panel
# 582                                    15.6-inch FHD IPS
# 583                      13.5 inch WUXGA IPS Touchscreen
# 584                                    14.0 inch FHD IPS
# 585                         14inch WUXGA IPS Touchscreen
# 586                         14inch WUXGA IPS Touchscreen
# 587                              13.3" WUXGA IPS Display
# 588                              13.3" WUXGA IPS Display
# 589                              13.3" WUXGA IPS Display
# 590                        13.3" WUXGA IPS Touch Display
# 591                        13.3" WUXGA IPS Touch Display
# 592                              13.3" WUXGA IPS Display
# 593                              13.3" WUXGA IPS Display
# 594                              13.3" WUXGA IPS Display
# 595                              13.3" WUXGA IPS Display
# 596                        13.3" WUXGA IPS Touch Display
# 597                        13.3 inch FHD IPS Touchscreen
# 598                        13.3" WUXGA IPS Touch Display
# 599                        13.3" WUXGA IPS Touch Display
# 600                        13.3" WUXGA IPS Touch Display
# 601                                   13.3inch WUXGA IPS
# 602                            15.6-inch FHD IPS Display
# 603                              14-inch FHD IPS Display
# 604                              14-inch FHD IPS Display
# 605                              14-inch FHD IPS Display
# 606                                    16 inch WUXGA IPS
# 607                              14-inch FHD IPS Display
# 608                              14-inch FHD IPS Display
# 609                                    16 inch WUXGA IPS
# 610                        16 inch WUXGA IPS Touchscreen
# 611                        16 inch WUXGA IPS Touchscreen
# 612              14.2 inch 3024 x 1964 Liquid Retina XDR
# 613                                      14 inch FHD IPS
# 614                              14.0 inch FHD IPS Touch
# 615                                          14 inch FHD
# 616                                      13.3" WUXGA IPS
# 617                                      14" FHD Display
# 618                                    15.6" FHD Display
# 619                                  14" WUXGA IPS Touch
# 620                                15.6" UHD IPS 400nits
# 621                                  15.6" FHD IPS Touch
# 622                                      14" FHD Display
# 623                                      14" FHD Display
# 624                        17inch QHD+ 165Hz Touchscreen
# 625                         16inch QHD+ 120Hz Touchpanel
# 626                         16inch QHD+ 120Hz Touchpanel
# 627                                    16inch FHD+ 144Hz
# 628                                    16inch FHD+ 144Hz
# 629                        17inch QHD+ 165Hz Touchscreen
# 630                                    16inch FHD+ 144Hz
# 631                        17inch QHD+ 165Hz Touchscreen
# 632                              15.6 inch FHD IPS Touch
# 633                                    14.0 inch FHD IPS
# 634                         16 inch QHD+ 165Hz Pen Touch
# 635                      14.0 inch WQXGA DreamColour IPS
# 636                                14 inch FHD IPS Touch
# 637                                16 inch 4K OLED Touch
# 638                            15.6 inch FHD IPS Display
# 639                           15.6 inch FHD Touch Screen
# 640                           15.6 inch FHD Touch Screen
# 641                                    15.6 inch FHD IPS
# 642                              14inch FHD IPS Sureview
# 643                              17.3 inch FHD IPS 144Hz
# 644                                    15.6 inch UHD IPS
# 645                           14.0 inch FHD IPS 400 Nits
# 646                              14.0 inch FHD IPS Touch
# 647                                         2TB SATA HDD
# 649                      15.6 inch UHD 4K IPS DreamColor
# 650                      15.6 inch UHD 4K IPS DreamColor
# 651                            15.6 inch FHD WVA Display
# 652                       15.6 inch 4K OLED Touch Screen
# 653                            15.6 inch FHD WVA Display
# 654                                    15.6 inch FHD IPS
# 655                           15.6 inch FHD Touch Screen
# 656                           15.6 inch FHD Touch Screen
# 657                                     16 inch FHD+ IPS
# 658                        16 inch FHD+ IPS Touch Screen
# 659                                     16 inch QHD+ IPS
# 660                              16 inch WUXGA IPS Touch
# 661                                    15.6 inch FHD IPS
# 662                           14.0 inch FHD IPS 400 Nits
# 663                                    15.6 inch FHD IPS
# 664    15.6 inch FHD IPS 500 nits 100% sRGB Dolby Vision
# 665               15.6 inch FHD IPS Touch Screen Display
# 666                            15.6 inch FHD IPS Display
# 667                                    15.6 inch FHD IPS
# 668                                    15.6 inch FHD IPS
# 669                           15.6 inch UHD 4K IPS Touch
# 670                              17.3 inch FHD IPS 144Hz
# 671                                    15.6 inch FHD IPS
# 672                              15.6 inch FHD+ 500 nits
# 674                           15.6 inch FHD Touch Screen
# 675                           15.6 inch FHD Touch Screen
# 676                                    16inch UHD OLED ,
# 677                                   14 inch QHD+ Touch
# 678                                  16 inch WUXGA Touch
# 679                                  16 inch WUXGA Touch
# 680                                16 inch 4K OLED Touch
# 681                              15.6 inch FHD+ 500 nits
# 682                                    15.6 inch FHD IPS
# 683                                    15.6 inch FHD IPS
# 684                                    16 inch QHD+ 60Hz
# 685                                    17inch QHD+ 165Hz
# 686                                   17.3inch UHD 144Hz
# 687                        17inch QHD+ 165Hz Touchscreen

# %%
# Create DISPLAY_SIZE column
laptop_modify['DISPLAY_SIZE'] = laptop_modify.DISPLAY

# %% [markdown]
# ## CPU data transformation
#
# Add brand column to cpu data.
#
# Extract processor model as primary key.

# %%
cpu_original = pd.read_csv(cwd + '/datasets/processor_data/cpu_data2023-03-21.csv', quotechar="'")
cpu_modify = cpu_original.copy()
# Convert CPU Mark to integer
cpu_modify['CPU Mark'] = cpu_modify['CPU Mark'].str.replace(',', '').astype(int)
cpu_modify
# Out:
#                                 CPU Name  CPU Mark
# 0                AArch64 rev 2 (aarch64)      2267
# 1                AArch64 rev 4 (aarch64)      1824
# 2                            AC8257V/WAB       711
# 3                             AMD 3015Ce      2067
# 4                              AMD 3015e      2709
# ...                                  ...       ...
# 4104   ZHAOXIN KaiXian KX-6640MA@2.2+GHz      1549
# 4105     ZHAOXIN KaiXian KX-U6580@2.5GHz      3227
# 4106    ZHAOXIN KaiXian KX-U6780A@2.7GHz      3881
# 4107  ZHAOXIN KaiXian ZX-C+ C4700@2.0GHz      1547
# 4108                               天玑900      4259
#
# [4109 rows x 2 columns]

# %% [markdown]
# Remove CPU models not offered for current laptops
#
# *Note: Filtering based of anecdotal observations. A better way of filtering would be to include the 'CPU First Seen on Charts' and 'CPU Class' in the scraped data, and filter based off these two columns. However, the anecdotal filter is sufficient for the current dataset and the scope of the project currently.*

# %%
# Remove processors not from: Intel, AMD, Apple
cpu_modify = cpu_modify.drop(cpu_modify[~cpu_modify['CPU Name'].str.contains('Intel|AMD|Apple')].index)
# Remove processors that are not within the following lineup-
# Intel: Celeron, Pentium, Core, Xeon
# AMD: Ryzen, Athlon
# Apple: Apple silicon (M series)
cpu_modify = cpu_modify.drop(cpu_modify[~cpu_modify['CPU Name'].str.contains('Celeron|Pentium|Core|Xeon|Ryzen|Athlon|Apple| M\d')].index)
# Remove remaining mobile processors
cpu_modify = cpu_modify.drop(cpu_modify[cpu_modify['CPU Name'].str.contains('Mobile')].index)
# Remove CPUs with a CPU Mark below 1500
cpu_modify = cpu_modify.drop(cpu_modify[cpu_modify['CPU Mark']<1900].index)
cpu_modify
# Out:
#                         CPU Name  CPU Mark
# 169             AMD Athlon 200GE      4102
# 170             AMD Athlon 220GE      4424
# 171             AMD Athlon 240GE      4534
# 175             AMD Athlon 3000G      4482
# 176             AMD Athlon 300GE      4256
# ...                          ...       ...
# 3599  Intel Xeon X5680 @ 3.33GHz      6794
# 3600  Intel Xeon X5687 @ 3.60GHz      5288
# 3601  Intel Xeon X5690 @ 3.47GHz      6967
# 3602  Intel Xeon X5698 @ 4.40GHz      3447
# 3603  Intel Xeon X6550 @ 2.00GHz      1936
#
# [1893 rows x 2 columns]

# %%
# Remove the unnecessary clockspeed in some of the CPU Names
cpu_modify['CPU Name'] = cpu_modify['CPU Name'].str.split(pat='@', expand=True)[0]
cpu_modify['CPU Name'].str.strip()

# Create Column for CPU Brand
cpu_Conditions = [
    cpu_modify['CPU Name'].str.contains('Intel', case=False),
    cpu_modify['CPU Name'].str.contains('AMD', case=False),
    cpu_modify['CPU Name'].str.contains('Apple', case=False)
]
cpu_Values = ['Intel', 'AMD', 'Apple']

cpu_modify['CPU Brand'] = np.select(cpu_Conditions, cpu_Values, default='Unknown')
cpu_modify
# Out:
#                CPU Name  CPU Mark CPU Brand
# 169    AMD Athlon 200GE      4102       AMD
# 170    AMD Athlon 220GE      4424       AMD
# 171    AMD Athlon 240GE      4534       AMD
# 175    AMD Athlon 3000G      4482       AMD
# 176    AMD Athlon 300GE      4256       AMD
# ...                 ...       ...       ...
# 3599  Intel Xeon X5680       6794     Intel
# 3600  Intel Xeon X5687       5288     Intel
# 3601  Intel Xeon X5690       6967     Intel
# 3602  Intel Xeon X5698       3447     Intel
# 3603  Intel Xeon X6550       1936     Intel
#
# [1893 rows x 3 columns]

# %%
# Create column for CPU Model and set as index
intel_regex = r'\s(([A-Z][A-Z0-9-]*|i.*)?\d{3,}\w*)'
amd_regex = r'\s((\w+-)?\d{3,}\w*)'
apple_regex = r'\s(M\d.*Core)'

def extract_cpu_model(row):
    cpu_name = row['CPU Name']
    cpu_brand = row['CPU Brand']

    if cpu_brand == 'Intel':
        match = re.search(intel_regex, cpu_name)
        if match:
            return match.group(1)
    if cpu_brand == 'AMD':
        match = re.search(amd_regex, cpu_name)
        if match:
            return match.group(1)
    if cpu_brand == 'Apple':
        match = re.search(apple_regex, cpu_name)
        if match:
            return match.group(1)
        
    return 'Unknown'

cpu_modify['CPU Model'] = cpu_modify.apply(extract_cpu_model, axis = 1)

# Entries where the CPU Model extraction failed
cpu_modify = cpu_modify.drop(cpu_modify[cpu_modify['CPU Model'] == 'Unknown'].index)

# Duplicate check
cpu_modify['CPU Model'].value_counts()
# Out:
# E3-1225     5
# E3-1220     5
# E3-1230     5
# E3-1275     5
# E3-1240     5
#            ..
# i5-3320M    1
# i5-3317U    1
# i5-3230M    1
# i5-3210M    1
# X6550       1
# Name: CPU Model, Length: 1655, dtype: int64

# %%
def agg_cpu_model(group):
    if len(group) == 1:
        return group.iloc[0]
    else:
        # For duplicate values, it's presumably the same CPU under two different CPU names.
        # Take the shorter of the two names and average the CPU Mark.
        # Note: Averaging the CPU Marks is sufficient for practical purposes as the two values should be similar.
        # If we wanted to be pedantic, PassMark shows the number of samples for each CPU Mark and we could recalculate a precise value.
        shorter_name_idx = group['CPU Name'].str.len().idxmin()
        shorter_name = group.loc[shorter_name_idx, 'CPU Name']
        avg_mark = group['CPU Mark'].mean()
        brand = group.iloc[0]['CPU Brand']
        return pd.Series({'CPU Name': shorter_name, 'CPU Mark': avg_mark, 'CPU Brand': brand})

cpu_modify = cpu_modify.groupby('CPU Model').apply(agg_cpu_model)
cpu_modify = cpu_modify.unstack()
cpu_modify.drop(columns='CPU Model', inplace=True)
cpu_modify
# Out:
#           CPU Brand CPU Mark                CPU Name
# CPU Model
# 1200            AMD   6309.5        AMD Ryzen 3 1200
# 1300            AMD     7234    AMD Ryzen 3 PRO 1300
# 1300X           AMD     6957       AMD Ryzen 3 1300X
# 1400            AMD     7756        AMD Ryzen 5 1400
# 1403          Intel     2284  Intel Pentium 1403 v2
# ...             ...      ...                     ...
# i9-9940X      Intel    28402    Intel Core i9-9940X
# i9-9960X      Intel    30354    Intel Core i9-9960X
# i9-9980HK     Intel    14493   Intel Core i9-9980HK
# i9-9980XE     Intel    32263   Intel Core i9-9980XE
# i9-9990XE     Intel    30162   Intel Core i9-9990XE
#
# [1655 rows x 3 columns]

# %% [markdown]
# # GPU data transformation
# Add brand column to the dataset.
#
# Extract GPU Model from GPU Name.

# %%
gpu_original = pd.read_csv(cwd + '/datasets/downloaded_data/GPU_Benchmarks_Compilation/GPU_benchmarks_v7.csv', quotechar='"')
gpu_modify = gpu_original.copy()
gpu_modify
# Out:
#                                   gpuName  G3Dmark  G2Dmark    price  \
# 0                     GeForce RTX 3090 Ti    29094     1117  2099.99
# 1                     GeForce RTX 3080 Ti    26887     1031  1199.99
# 2                        GeForce RTX 3090    26395      999  1749.99
# 3                       Radeon RX 6900 XT    25458     1102  1120.31
# 4                        GeForce RTX 3080    24853     1003   999.00
# ...                                   ...      ...      ...      ...
# 2312  Intel 82852/82855 GM/GME Controller        1      107      NaN
# 2313                          Quadro2 Pro        1      143      NaN
# 2314                         Rage 128 Pro        1       40      NaN
# 2315             RAGE 128 PRO AGP 4X TMDS        1      142      NaN
# 2316                      S3 ProSavageDDR        1       41      NaN
#
#       gpuValue    TDP  powerPerformance  testDate     category
# 0        13.85  450.0             64.65      2022      Unknown
# 1        22.41  350.0             76.82      2021      Desktop
# 2        15.08  350.0             75.41      2020      Desktop
# 3        22.72  300.0             84.86      2020      Desktop
# 4        24.88  320.0             77.66      2020      Desktop
# ...        ...    ...               ...       ...          ...
# 2312       NaN    NaN               NaN      2010      Unknown
# 2313       NaN    NaN               NaN      2009  Workstation
# 2314       NaN    NaN               NaN      2009      Unknown
# 2315       NaN    NaN               NaN      2009      Unknown
# 2316       NaN    NaN               NaN      2009      Unknown
#
# [2317 rows x 9 columns]

# %%
# Remove irrelevant rows and columns
gpu_modify = gpu_modify[(gpu_modify.category != 'Desktop') & (gpu_modify.category != 'Workstation')]
gpu_modify.drop(gpu_modify[gpu_modify['gpuName'].str.contains('\+|/')].index, inplace=True)
gpu_modify.drop(gpu_modify[~gpu_modify['gpuName'].str.contains('Intel|AMD|Nvidia|GeForce|Radeon|RTX|GTX', case=False)].index, inplace=True)
gpu_modify.drop(gpu_modify[gpu_modify['gpuName'].str.contains('Radeon HD', case=False)].index, inplace=True)
gpu_modify.drop(columns=['G2Dmark', 'price', 'gpuValue', 'TDP', 'powerPerformance', 'testDate'], inplace=True)
gpu_modify.drop(gpu_modify[gpu_modify['G3Dmark']<700].index, inplace=True)
gpu_modify.head()
# Out:
#                            gpuName  G3Dmark category
# 0              GeForce RTX 3090 Ti    29094  Unknown
# 11                       RTX A4500    21546  Unknown
# 18  GeForce RTX 3080 Ti Laptop GPU    19507  Unknown
# 23                Radeon PRO W6800    18802  Unknown
# 26  GeForce RTX 3070 Ti Laptop GPU    18490  Unknown

# %%
# Create brand column
gpu_Conditions = [
    gpu_modify.gpuName.str.contains('Intel', case = False),
    gpu_modify.gpuName.str.contains('Nvidia|GeForce|GTX', case = False),
    gpu_modify.gpuName.str.contains('AMD|Radeon|RTX', case=False)
]
gpu_Values = ['Intel', 'Nvidia', 'AMD']

gpu_modify['gpuBrand'] = np.select(gpu_Conditions, gpu_Values, default='Unknown')
gpu_modify.head(0)
# Out:
# Empty DataFrame
# Columns: [gpuName, G3Dmark, category, gpuBrand]
# Index: []

# %%
# Extract gpu model
def extract_gpu_model(row):
    gpu_regex = r'\b[A-Z0-9-]*\d\d[A-Z0-9-]*\b'
    brand = row.gpuBrand
    name = row.gpuName

    if brand == 'Nvidia':
        gpu_model = re.search(gpu_regex, name)
        if gpu_model != None:
            gpu_model = gpu_model.group(0)
            if 'Ti' in name:
                gpu_model += ' Ti'
            if 'Super' in name:
                gpu_model += ' Super'
            return gpu_model
        else:
            return 'Unknown model'
        
    elif brand == 'AMD':
        gpu_model = re.search(gpu_regex, name)
        if gpu_model != None:
            gpu_model = gpu_model.group(0)
            if 'XT' in name:
                gpu_model += ' XT'
            return gpu_model
        else:
            return 'Unknown model'
        
    elif brand == 'Intel':
        intelName = name.split(' ')
        gpu_model = ' '.join(intelName[1:])
        return gpu_model

    else:
        return 'Unknown brand'

gpu_modify['gpuModel'] = gpu_modify.apply(extract_gpu_model, axis=1)
gpu_modify.head()
# Out:
#                            gpuName  G3Dmark category gpuBrand gpuModel
# 0              GeForce RTX 3090 Ti    29094  Unknown   Nvidia  3090 Ti
# 11                       RTX A4500    21546  Unknown      AMD    A4500
# 18  GeForce RTX 3080 Ti Laptop GPU    19507  Unknown   Nvidia  3080 Ti
# 23                Radeon PRO W6800    18802  Unknown      AMD    W6800
# 26  GeForce RTX 3070 Ti Laptop GPU    18490  Unknown   Nvidia  3070 Ti

# %%
# Check for duplicate gpu models
duplicateGpu = gpu_modify.groupby(by=['gpuBrand', 'gpuModel']).filter(lambda x: len(x)>1)
duplicateGpu = duplicateGpu[duplicateGpu.gpuModel != 'Unknown model']
print(duplicateGpu.to_string())
# Out:
#                                       gpuName  G3Dmark             category gpuBrand   gpuModel
# 52                  GeForce RTX 2080 (Mobile)    15107               Mobile   Nvidia       2080
# 54                   Quadro RTX 5000 (Mobile)    14832  Mobile, Workstation      AMD       5000
# 65          Quadro RTX 5000 with Max-Q Design    13893  Mobile, Workstation      AMD       5000
# 70                             RTX A2000 12GB    13688              Unknown      AMD      A2000
# 71         GeForce RTX 2080 with Max-Q Design    13681               Mobile   Nvidia       2080
# 74          Quadro RTX 4000 with Max-Q Design    13622               Mobile      AMD       4000
# 77                       RTX A3000 Laptop GPU    13263  Mobile, Workstation      AMD      A3000
# 80                                  RTX A2000    13128              Unknown      AMD      A2000
# 81                   Quadro RTX 4000 (Mobile)    13008               Mobile      AMD       4000
# 84                           GeForce RTX 3050    12718              Unknown   Nvidia       3050
# 89                  GeForce RTX 2070 (Mobile)    12354               Mobile   Nvidia       2070
# 93         GeForce RTX 2070 with Max-Q Design    12062               Mobile   Nvidia       2070
# 106                 GeForce RTX 2060 (Mobile)    11355               Mobile   Nvidia       2060
# 108                           Quadro RTX 3000    11122  Mobile, Workstation      AMD       3000
# 113                 GeForce GTX 1070 (Mobile)    10465               Mobile   Nvidia       1070
# 114                          Radeon Pro 5600M    10200               Mobile      AMD      5600M
# 115              GeForce GTX 1660 Ti (Mobile)    10176               Mobile   Nvidia    1660 Ti
# 116                      RTX A2000 Laptop GPU    10148  Mobile, Workstation      AMD      A2000
# 121        GeForce GTX 1070 with Max-Q Design    10030               Mobile   Nvidia       1070
# 122                 RTX A3000 12GB Laptop GPU     9975              Unknown      AMD      A3000
# 124        GeForce RTX 2060 with Max-Q Design     9743               Mobile   Nvidia       2060
# 144               GeForce RTX 3050 Laptop GPU     9037               Mobile   Nvidia       3050
# 148                     Radeon Ryzen 7 4800HS     8842              Unknown      AMD     4800HS
# 151         Quadro RTX 3000 with Max-Q Design     8754               Mobile      AMD       3000
# 155     GeForce GTX 1660 Ti with Max-Q Design     8646               Mobile   Nvidia    1660 Ti
# 160                     Radeon Ryzen 9 5900HS     8428              Unknown      AMD     5900HS
# 166                 GeForce GTX 1060 (Mobile)     8161               Mobile   Nvidia       1060
# 174        GeForce GTX 1060 with Max-Q Design     7907               Mobile   Nvidia       1060
# 181                      Radeon RX 580 2048SP     7768              Unknown      AMD        580
# 183                            Radeon Pro 580     7753              Unknown      AMD        580
# 187                           Radeon Pro 5300     7522              Unknown      AMD       5300
# 189                       GeForce GTX 1650 Ti     7490               Mobile   Nvidia    1650 Ti
# 192                           RadeonT RX 5300     7321              Unknown      AMD       5300
# 196                           Radeon RX 5600M     7157               Mobile      AMD      5600M
# 198       Ryzen 7 4800HS with Radeon Graphics     6999              Unknown      AMD     4800HS
# 199                 GeForce GTX 1650 (Mobile)     6969               Mobile   Nvidia       1650
# 203                          Radeon Pro 5500M     6763              Unknown      AMD      5500M
# 214     GeForce GTX 1650 Ti with Max-Q Design     6342               Mobile   Nvidia    1650 Ti
# 226              GeForce GTX 1050 Ti (Mobile)     5919               Mobile   Nvidia    1050 Ti
# 229        GeForce GTX 1650 with Max-Q Design     5884               Mobile   Nvidia       1650
# 230                          Radeon Pro 5300M     5840              Unknown      AMD      5300M
# 248     GeForce GTX 1050 Ti with Max-Q Design     5372               Mobile   Nvidia    1050 Ti
# 254                      Radeon Ryzen 7 4800H     5178              Unknown      AMD      4800H
# 262       Ryzen 9 5900HS with Radeon Graphics     5049              Unknown      AMD     5900HS
# 285                 GeForce GTX 1050 (Mobile)     4462               Mobile   Nvidia       1050
# 312                           Radeon RX 5500M     4010               Mobile      AMD      5500M
# 330        GeForce GTX 1050 with Max-Q Design     3785               Mobile   Nvidia       1050
# 335                           Radeon Pro 560X     3678              Unknown      AMD       560X
# 341        GeForce GTX 680M KY_Bullet Edition     3569              Unknown   Nvidia       680M
# 343                           Radeon RX 5300M     3562               Mobile      AMD      5300M
# 368                              GeForce 770M     3246              Unknown   Nvidia       770M
# 373                          RadeonT RX 5500M     3166              Unknown      AMD      5500M
# 379                     Radeon Ryzen 9 5900HX     3126              Unknown      AMD     5900HX
# 385                          GeForce GTX 680M     3077               Mobile   Nvidia       680M
# 397       Ryzen 9 5900HX with Radeon Graphics     2968              Unknown      AMD     5900HX
# 400                            Radeon R9 M380     2931               Mobile      AMD       M380
# 402    Ryzen 7 PRO 4700G with Radeon Graphics     2880              Unknown      AMD      4700G
# 410        Ryzen 7 5800H with Radeon Graphics     2833              Unknown      AMD      5800H
# 413                          GeForce GTX 770M     2786               Mobile   Nvidia       770M
# 415                      Radeon Ryzen 7 5700G     2782              Unknown      AMD      5700G
# 416                 Radeon Ryzen 7 PRO 5750GE     2771              Unknown      AMD     5750GE
# 417                      Radeon Ryzen 7 5800H     2759              Unknown      AMD      5800H
# 421                      Radeon Ryzen 5 4600H     2747              Unknown      AMD      4600H
# 424                            Radeon Pro 450     2723              Unknown      AMD        450
# 426        Ryzen 9 4900H with Radeon Graphics     2714              Unknown      AMD      4900H
# 428        Ryzen 7 5700G with Radeon Graphics     2709              Unknown      AMD      5700G
# 432                      Radeon Ryzen 5 5600H     2696              Unknown      AMD      5600H
# 434                      Radeon Ryzen 9 4900H     2685              Unknown      AMD      4900H
# 435    Ryzen 7 Pro 4750G with Radeon Graphics     2682              Unknown      AMD      4750G
# 443                  MONSTER GeForce GTX 675M     2637              Unknown   Nvidia       675M
# 446   Ryzen 7 PRO 5750GE with Radeon Graphics     2613              Unknown      AMD     5750GE
# 449                  Radeon Ryzen 7 PRO 4750G     2604              Unknown      AMD      4750G
# 453        Ryzen 5 5600G with Radeon Graphics     2595              Unknown      AMD      5600G
# 454    Ryzen 7 PRO 5750G with Radeon Graphics     2591              Unknown      AMD      5750G
# 455                      Radeon Ryzen 7 4700G     2580              Unknown      AMD      4700G
# 456                          GeForce GTX 850M     2574               Mobile   Nvidia       850M
# 457   Ryzen 7 PRO 4750GE with Radeon Graphics     2550              Unknown      AMD     4750GE
# 460                      Radeon Ryzen 5 5600G     2545              Unknown      AMD      5600G
# 469    Ryzen 5 PRO 5650G with Radeon Graphics     2513              Unknown      AMD      5650G
# 470                     Radeon Ryzen 7 4700GE     2508              Unknown      AMD     4700GE
# 471   Ryzen 5 PRO 5650GE with Radeon Graphics     2506              Unknown      AMD     5650GE
# 472       Ryzen 7 4700GE with Radeon Graphics     2496              Unknown      AMD     4700GE
# 474        Ryzen 7 5800U with Radeon Graphics     2467              Unknown      AMD      5800U
# 476    Ryzen 7 PRO 5850U with Radeon Graphics     2440              Unknown      AMD      5850U
# 478                  Radeon Ryzen 5 PRO 4650G     2418              Unknown      AMD      4650G
# 481                     Radeon RX Vega 11 PRD     2402              Unknown      AMD         11
# 482       Ryzen 3 4300GE with Radeon Graphics     2402              Unknown      AMD     4300GE
# 483    Ryzen 5 Pro 4650G with Radeon Graphics     2395              Unknown      AMD      4650G
# 484        Ryzen 5 5600H with Radeon Graphics     2387              Unknown      AMD      5600H
# 488                 Radeon Ryzen 5 PRO 5650GE     2363              Unknown      AMD     5650GE
# 490        Ryzen 7 4800U with Radeon Graphics     2344              Unknown      AMD      4800U
# 491    Ryzen 3 PRO 5350G with Radeon Graphics     2341              Unknown      AMD      5350G
# 495                  Radeon Ryzen 7 PRO 5850U     2333              Unknown      AMD      5850U
# 496                      Radeon Ryzen 7 5800U     2321              Unknown      AMD      5800U
# 500                     Radeon Ryzen 3 4300GE     2306              Unknown      AMD     4300GE
# 506                      Radeon Ryzen 7 4800U     2273              Unknown      AMD      4800U
# 507              Radeon Pro Ryzen 7 PRO 5850U     2271              Unknown      AMD      5850U
# 518        Ryzen 3 5300G with Radeon Graphics     2223              Unknown      AMD      5300G
# 519                  Radeon Ryzen 5 PRO 5650G     2212              Unknown      AMD      5650G
# 521                 Radeon Ryzen 7 PRO 4750GE     2200              Unknown      AMD     4750GE
# 522    Ryzen 3 Pro 4350G with Radeon Graphics     2190              Unknown      AMD      4350G
# 523        Ryzen 7 4700G with Radeon Graphics     2187              Unknown      AMD      4700G
# 524                      Radeon Ryzen 5 4600G     2186              Unknown      AMD      4600G
# 525                            RadeonT R7 450     2185              Unknown      AMD        450
# 526    Ryzen 5 PRO 5650U with Radeon Graphics     2184              Unknown      AMD      5650U
# 527   Ryzen 3 PRO 4350GE with Radeon Graphics     2181              Unknown      AMD     4350GE
# 530                  Radeon Ryzen 3 PRO 4350G     2162              Unknown      AMD      4350G
# 531        Ryzen 5 5600U with Radeon Graphics     2160              Unknown      AMD      5600U
# 533                  Radeon Ryzen 7 PRO 5750G     2154              Unknown      AMD      5750G
# 535                  Radeon Ryzen 5 PRO 5650U     2138              Unknown      AMD      5650U
# 539        Ryzen 7 4800H with Radeon Graphics     2113              Unknown      AMD      4800H
# 545        Ryzen 5 4600G with Radeon Graphics     2062              Unknown      AMD      4600G
# 548                      Radeon Ryzen 7 4700U     2044              Unknown      AMD      4700U
# 549                 Radeon Ryzen 5 PRO 4650GE     2038              Unknown      AMD     4650GE
# 551        Ryzen 7 4700U with Radeon Graphics     2033              Unknown      AMD      4700U
# 552    Ryzen 7 PRO 4750U with Radeon Graphics     2028              Unknown      AMD      4750U
# 553                  Radeon Ryzen 7 PRO 4750U     2024              Unknown      AMD      4750U
# 555                      Radeon Ryzen 5 5600U     2015              Unknown      AMD      5600U
# 558    Ryzen 5 PRO 4500U with Radeon Graphics     2008              Unknown      AMD      4500U
# 568   Ryzen 5 PRO 4650GE with Radeon Graphics     1977              Unknown      AMD     4650GE
# 580        Ryzen 5 4600U with Radeon Graphics     1951              Unknown      AMD      4600U
# 584        Ryzen 5 4600H with Radeon Graphics     1939              Unknown      AMD      4600H
# 586                          GeForce GTX 675M     1934               Mobile   Nvidia       675M
# 593        Ryzen 3 4300G with Radeon Graphics     1903              Unknown      AMD      4300G
# 604                            Radeon Vega 11     1847              Unknown      AMD         11
# 611        Ryzen 5 4500U with Radeon Graphics     1813              Unknown      AMD      4500U
# 613                           RadeonT RX 560X     1810              Unknown      AMD       560X
# 615                              RadeonT 540X     1804              Unknown      AMD       540X
# 616                      Radeon Ryzen 5 4600U     1802              Unknown      AMD      4600U
# 618               Radeon RX Vega 11 Processor     1800              Unknown      AMD         11
# 619                      Radeon Ryzen 5 4500U     1800              Unknown      AMD      4500U
# 625   Ryzen 3 PRO 4200GE with Radeon Graphics     1784              Unknown      AMD     4200GE
# 636        Ryzen 3 5400U with Radeon Graphics     1734              Unknown      AMD      5400U
# 638                 Radeon Ryzen 3 PRO 4200GE     1712              Unknown      AMD     4200GE
# 641                  Radeon Ryzen 5 PRO 4650U     1699              Unknown      AMD      4650U
# 643    Ryzen 5 PRO 4650U with Radeon Graphics     1696              Unknown      AMD      4650U
# 644                         Radeon RX Vega 10     1694              Unknown      AMD         10
# 647                            Radeon R7 M380     1669              Unknown      AMD       M380
# 663                      Radeon Ryzen 3 4300G     1596              Unknown      AMD      4300G
# 670                            RadeonT RX 640     1565              Unknown      AMD        640
# 672                            Radeon Vega 10     1557              Unknown      AMD         10
# 673    Ryzen 3 PRO 5450U with Radeon Graphics     1556              Unknown      AMD      5450U
# 680    Ryzen 3 PRO 4300U with Radeon Graphics     1543              Unknown      AMD      4300U
# 683    Ryzen 3 PRO 4450U with Radeon Graphics     1538              Unknown      AMD      4450U
# 684                             Radeon RX 640     1537      Desktop, Mobile      AMD        640
# 690                  Radeon Ryzen 3 PRO 4450U     1505              Unknown      AMD      4450U
# 697                           Radeon R9 M365X     1482               Mobile      AMD      M365X
# 699                     Radeon Vega 10 Mobile     1465              Unknown      AMD         10
# 700                 Radeon Ryzen 3 PRO 4350GE     1464              Unknown      AMD     4350GE
# 712                  Radeon Ryzen 3 PRO 5350G     1408              Unknown      AMD      5350G
# 713                      Radeon Ryzen 3 5300G     1406              Unknown      AMD      5300G
# 715                               Radeon 540X     1398              Unknown      AMD       540X
# 725        Ryzen 3 4300U with Radeon Graphics     1348              Unknown      AMD      4300U
# 736                      Radeon Ryzen 3 4300U     1310              Unknown      AMD      4300U
# 781                      Radeon Ryzen 3 5400U     1183              Unknown      AMD      5400U
# 796                  Radeon Ryzen 3 PRO 5450U     1143              Unknown      AMD      5450U
# 799                Radeon R7 A10-9700E RADEON     1138              Unknown      AMD  A10-9700E
# 807                    Radeon R7 PRO A12-9800     1117              Unknown      AMD   A12-9800
# 809                             Radeon R7 430     1110              Unknown      AMD        430
# 817                 GeForce GTX 850M - MODDED     1092              Unknown   Nvidia       850M
# 837                     Radeon R7 PRO A8-9600     1049              Unknown      AMD    A8-9600
# 855                            RadeonT R5 430     1016              Unknown      AMD        430
# 868                             Radeon R5 340      996              Unknown      AMD        340
# 871                 Radeon R7 A12-9800 RADEON      989              Unknown      AMD   A12-9800
# 880                 Radeon R7 A10-9700 RADEON      975              Unknown      AMD   A10-9700
# 892                   Radeon R7 A10 PRO-7850B      958              Unknown      AMD        A10
# 910                Radeon R7 A12-9800E RADEON      941              Unknown      AMD  A12-9800E
# 911                   Radeon R7 PRO A12-9800E      940              Unknown      AMD  A12-9800E
# 912                             Radeon R5 430      939              Unknown      AMD        430
# 915                   Radeon R7 PRO A10-9700E      933              Unknown      AMD  A10-9700E
# 917                             Radeon R7 340      931              Unknown      AMD        340
# 948                           Radeon R7 M365X      884              Unknown      AMD      M365X
# 997             Radeon R7 A10 Extreme Edition      816              Unknown      AMD        A10
# 1008                 Radeon R7 A8-9600 RADEON      798              Unknown      AMD    A8-9600
# 1035                   Radeon R7 PRO A10-9700      771              Unknown      AMD   A10-9700
# 1036                             GeForce 730A      769              Unknown   Nvidia       730A
# 1069                          GeForce GT 730A      743              Unknown   Nvidia       730A

# %%
# Set the index to gpuName for dealing with duplicates
gpu_modify = gpu_modify.set_index('gpuName')

# %%
# Clean up duplicate gpu models
# If there are specified laptop versions, use the laptop versions
# Else use the non-laptop versions
# Average the marks across the duplicates
for model in duplicateGpu.gpuModel.unique():
    duplicateNames = gpu_modify[gpu_modify.gpuModel == model].index.values

    laptopInName = []
    laptopNotInName = []
    for gpuName in duplicateNames:
        if 'Laptop' in gpuName:
            laptopInName += [gpuName]
        else:
            laptopNotInName += [gpuName]

    if laptopInName != []:
        # remove laptop not in name
        averageMark = gpu_modify.loc[laptopInName].G3Dmark.mean()
        gpu_modify.drop(laptopNotInName, inplace=True)
        selectName = {'name': '', 'length': 999}
        for name in laptopInName:
            if (len(name)) < selectName['length']:
                selectName['length'] = len(name)
                selectName['name'] = name
        laptopInName.remove(selectName['name'])
        gpu_modify.at[selectName['name'], 'G3Dmark'] = averageMark
        gpu_modify.drop(laptopInName, inplace=True)
    else:
        averageMark = gpu_modify.loc[laptopNotInName].G3Dmark.mean()
        selectName = {'name': '', 'length': 999}
        for name in laptopNotInName:
            if (len(name)) < selectName['length']:
                selectName['length'] = len(name)
                selectName['name'] = name
        laptopNotInName.remove(selectName['name'])
        gpu_modify.at[selectName['name'], 'G3Dmark'] = averageMark
        gpu_modify.drop(laptopNotInName, inplace=True)

gpu_modify
# Out:
#                                                     G3Dmark category gpuBrand  \
# gpuName
# GeForce RTX 3090 Ti                                 29094.0  Unknown   Nvidia
# RTX A4500                                           21546.0  Unknown      AMD
# GeForce RTX 3080 Ti Laptop GPU                      19507.0  Unknown   Nvidia
# Radeon PRO W6800                                    18802.0  Unknown      AMD
# GeForce RTX 3070 Ti Laptop GPU                      18490.0  Unknown   Nvidia
# ...                                                     ...      ...      ...
# Radeon R5 A10-9600P RADEON R5, 10 COMPUTE CORES 4C    716.0  Unknown      AMD
# Intel HD 5600                                         712.0  Unknown    Intel
# Radeon R7 A8-7650K                                    704.0  Unknown      AMD
# Radeon R7 A12-9700P RADEON                            703.0  Unknown      AMD
# GeForce GT 740A                                       702.0  Unknown   Nvidia
#
#                                                      gpuModel
# gpuName
# GeForce RTX 3090 Ti                                   3090 Ti
# RTX A4500                                               A4500
# GeForce RTX 3080 Ti Laptop GPU                        3080 Ti
# Radeon PRO W6800                                        W6800
# GeForce RTX 3070 Ti Laptop GPU                        3070 Ti
# ...                                                       ...
# Radeon R5 A10-9600P RADEON R5, 10 COMPUTE CORES 4C  A10-9600P
# Intel HD 5600                                         HD 5600
# Radeon R7 A8-7650K                                   A8-7650K
# Radeon R7 A12-9700P RADEON                          A12-9700P
# GeForce GT 740A                                          740A
#
# [394 rows x 4 columns]

# %%
print(gpu_modify.to_string())
# Out:
#                                                          G3Dmark             category gpuBrand                 gpuModel
# gpuName
# GeForce RTX 3090 Ti                                 29094.000000              Unknown   Nvidia                  3090 Ti
# RTX A4500                                           21546.000000              Unknown      AMD                    A4500
# GeForce RTX 3080 Ti Laptop GPU                      19507.000000              Unknown   Nvidia                  3080 Ti
# Radeon PRO W6800                                    18802.000000              Unknown      AMD                    W6800
# GeForce RTX 3070 Ti Laptop GPU                      18490.000000              Unknown   Nvidia                  3070 Ti
# Radeon Pro VII                                      16853.000000              Unknown      AMD            Unknown model
# GeForce RTX 3080 Laptop GPU                         16522.000000               Mobile   Nvidia                     3080
# RTX A4000 Laptop GPU                                16297.000000  Mobile, Workstation      AMD                    A4000
# RTX A5000 Laptop GPU                                16273.000000  Mobile, Workstation      AMD                    A5000
# RadeonT RX 6850M                                    15899.000000              Unknown      AMD                    6850M
# GeForce RTX 3070 Laptop GPU                         15231.000000               Mobile   Nvidia                     3070
# GeForce RTX 2080 (Mobile)                           14394.000000               Mobile   Nvidia                     2080
# Quadro RTX 5000 (Mobile)                            14362.500000  Mobile, Workstation      AMD                     5000
# Radeon Pro Vega II                                  14738.000000              Unknown      AMD            Unknown model
# Radeon Pro Vega 64X                                 14630.000000              Unknown      AMD                      64X
# GeForce RTX 2070 Super with Max-Q Design            14261.000000               Mobile   Nvidia               2070 Super
# Radeon PRO W6600                                    14212.000000              Unknown      AMD                    W6600
# GeForce RTX 2080 Super with Max-Q Design            14020.000000               Mobile   Nvidia               2080 Super
# Radeon RX 6600                                      13881.000000              Unknown      AMD                     6600
# RTX A3000 Laptop GPU                                11619.000000  Mobile, Workstation      AMD                    A3000
# Quadro RTX 4000 (Mobile)                            13315.000000               Mobile      AMD                     4000
# Radeon Pro V520 MxGPU                               12853.000000              Unknown      AMD                     V520
# GeForce RTX 3060 Laptop GPU                         12674.000000               Mobile   Nvidia                     3060
# Radeon Pro Vega 64                                  12402.000000              Unknown      AMD                       64
# GeForce RTX 2070 (Mobile)                           12208.000000               Mobile   Nvidia                     2070
# Radeon RX 6700S                                     11989.000000              Unknown      AMD                    6700S
# GeForce GTX 1080 with Max-Q Design                  11507.000000               Mobile   Nvidia                     1080
# Radeon Pro Vega 48                                  11504.000000              Unknown      AMD                       48
# Radeon RX 6700M                                     11499.000000              Unknown      AMD                    6700M
# GeForce RTX 2060 (Mobile)                           10549.000000               Mobile   Nvidia                     2060
# Quadro RTX 3000                                      9938.000000  Mobile, Workstation      AMD                     3000
# Radeon Pro SSG                                      10498.000000              Unknown      AMD            Unknown model
# Radeon Instinct MI25 MxGPU                          10466.000000              Unknown      AMD                     MI25
# GeForce GTX 1070 (Mobile)                           10247.500000               Mobile   Nvidia                     1070
# GeForce GTX 1660 Ti (Mobile)                         9411.000000               Mobile   Nvidia                  1660 Ti
# RTX A2000 Laptop GPU                                10148.000000  Mobile, Workstation      AMD                    A2000
# Radeon R9 Fury X                                    10088.000000              Unknown      AMD            Unknown model
# Radeon R9 Fury                                       9551.000000              Unknown      AMD            Unknown model
# Radeon Ryzen 9 4900HSS                               9461.000000              Unknown      AMD                  4900HSS
# GeForce RTX 3050 Ti Laptop GPU                       9452.000000               Mobile   Nvidia                  3050 Ti
# Radeon RX 6500 XT                                    9445.000000              Unknown      AMD                  6500 XT
# Radeon RX 6600M                                      9094.000000              Unknown      AMD                    6600M
# GeForce RTX 3050 Laptop GPU                          9037.000000               Mobile   Nvidia                     3050
# Radeon RX 6800M                                      9012.000000               Mobile      AMD                    6800M
# Radeon Ryzen 7 4800HS                                7920.500000              Unknown      AMD                   4800HS
# Radeon R9 290X                                       8794.000000              Unknown      AMD                     290X
# Radeon Ryzen 9 4900HS                                8572.000000              Unknown      AMD                   4900HS
# Radeon Ryzen 9 5900HS                                6738.500000              Unknown      AMD                   5900HS
# Radeon R9 290                                        8409.000000              Unknown      AMD                      290
# Radeon Pro 5500 XT                                   8298.000000              Unknown      AMD                  5500 XT
# GeForce GTX 1060 (Mobile)                            8034.000000               Mobile   Nvidia                     1060
# GeForce RTX 2050                                     8007.000000              Unknown   Nvidia                     2050
# Radeon Ryzen 5 4600HS                                7942.000000              Unknown      AMD                   4600HS
# Radeon Pro 580                                       7760.500000              Unknown      AMD                      580
# Radeon Pro 5300                                      7421.500000              Unknown      AMD                     5300
# GeForce GTX 1650 Ti                                  6916.000000               Mobile   Nvidia                  1650 Ti
# Ryzen 7 5800HS with Radeon Graphics                  7391.000000              Unknown      AMD                   5800HS
# GeForce GTX 980M                                     7317.000000               Mobile   Nvidia                     980M
# Radeon RX 5600M                                      8678.500000               Mobile      AMD                    5600M
# GeForce GTX 1650 (Mobile)                            6426.500000               Mobile   Nvidia                     1650
# Radeon RX 6400                                       6958.000000              Unknown      AMD                     6400
# Radeon RX Vega M GH                                  6734.000000              Unknown      AMD            Unknown model
# GeForce GTX 970XM FORCE                              6707.000000              Unknown   Nvidia                    970XM
# Radeon R9 285                                        6680.000000              Unknown      AMD                      285
# Radeon Pro 570                                       6337.000000              Unknown      AMD                      570
# Radeon Pro WX Vega M GL                              6049.000000               Mobile      AMD            Unknown model
# GeForce GTX 1050 Ti (Mobile)                         5645.500000               Mobile   Nvidia                  1050 Ti
# Radeon PRO W6400                                     5916.000000              Unknown      AMD                    W6400
# GeForce GTX 970M                                     5761.000000               Mobile   Nvidia                     970M
# Radeon Pro WX 7130                                   5722.000000               Mobile      AMD                     7130
# GeForce GTX 760 Ti OEM                               5427.000000              Unknown   Nvidia                   760 Ti
# Radeon Ryzen 7 4800H                                 3645.500000              Unknown      AMD                    4800H
# Radeon R9 M295X                                      5150.000000               Mobile      AMD                    M295X
# Radeon Pro Vega 20                                   5117.000000              Unknown      AMD                       20
# GeForce MX550                                        5090.000000              Unknown   Nvidia                    MX550
# Radeon R9 M395                                       4991.000000               Mobile      AMD                     M395
# GRID RTX6000P-6Q                                     4777.000000              Unknown      AMD              RTX6000P-6Q
# Radeon R9 M395X                                      4775.000000               Mobile      AMD                    M395X
# Radeon Sky 500                                       4736.000000              Unknown      AMD                      500
# Radeon Pro Vega 16                                   4683.000000              Unknown      AMD                       16
# Radeon Pro 465                                       4538.000000              Unknown      AMD                      465
# GeForce GTX 1050 (Mobile)                            4123.500000               Mobile   Nvidia                     1050
# GRID GTX P40-6                                       4340.000000              Unknown   Nvidia                    P40-6
# Radeon R9 270                                        4306.000000              Unknown      AMD                      270
# GRID RTX6000P-4Q                                     4283.000000              Unknown      AMD              RTX6000P-4Q
# GeForce GTX 680MX                                    4271.000000               Mobile   Nvidia                    680MX
# GeForce GTX 775M                                     4208.000000              Unknown   Nvidia                     775M
# Radeon RX 5500M                                      4646.333333               Mobile      AMD                    5500M
# GRID RTX8000-4Q                                      3961.000000              Unknown      AMD               RTX8000-4Q
# GeForce GTX 880M                                     3876.000000               Mobile   Nvidia                     880M
# GRID RTX8000P-2Q                                     3843.000000              Unknown      AMD              RTX8000P-2Q
# GeForce GTX 965M                                     3824.000000               Mobile   Nvidia                     965M
# GeForce GTX 780M                                     3755.000000               Mobile   Nvidia                     780M
# GeForce MX450                                        3743.000000              Unknown   Nvidia                    MX450
# Radeon Pro 560X                                      2744.000000              Unknown      AMD                     560X
# GRID RTX8000-2Q                                      3574.000000              Unknown      AMD               RTX8000-2Q
# Radeon RX 5300M                                      4701.000000               Mobile      AMD                    5300M
# Radeon Pro 560                                       3475.000000              Unknown      AMD                      560
# Radeon Pro 460                                       3453.000000              Unknown      AMD                      460
# GeForce GTX 960M                                     3419.000000               Mobile   Nvidia                     960M
# Radeon R9 M470X                                      3400.000000               Mobile      AMD                    M470X
# GeForce GTX 870M                                     3380.000000               Mobile   Nvidia                     870M
# Radeon R9 M290X                                      3375.000000               Mobile      AMD                    M290X
# Radeon E8870PCIe                                     3368.000000              Unknown      AMD            Unknown model
# Radeon RX Vega M GL                                  3315.000000              Unknown      AMD            Unknown model
# GeForce 770M                                         3016.000000              Unknown   Nvidia                     770M
# Radeon R9 M485X                                      3204.000000              Unknown      AMD                    M485X
# Radeon Pro 555                                       3141.000000              Unknown      AMD                      555
# Radeon Ryzen 9 5900HX                                3047.000000              Unknown      AMD                   5900HX
# Radeon Pro 455                                       3113.000000              Unknown      AMD                      455
# Intel G35 Express                                    3090.000000              Unknown    Intel              G35 Express
# GeForce GTX 680M                                     3323.000000               Mobile   Nvidia                     680M
# GeForce GTX 860M                                     3045.000000               Mobile   Nvidia                     860M
# Radeon R9 M390X                                      3021.000000               Mobile      AMD                    M390X
# Radeon R9 260                                        3018.000000              Unknown      AMD                      260
# Radeon R9 M380                                       2300.000000               Mobile      AMD                     M380
# GeForce MX350                                        2855.000000              Unknown   Nvidia                    MX350
# Radeon Pro V340 MxGPU                                2853.000000              Unknown      AMD                     V340
# Intel Iris Xe                                        2782.000000              Unknown    Intel                  Iris Xe
# Radeon Ryzen 7 5700G                                 2745.500000              Unknown      AMD                    5700G
# Radeon Ryzen 7 PRO 5750GE                            2692.000000              Unknown      AMD                   5750GE
# Radeon Ryzen 7 5800H                                 2796.000000              Unknown      AMD                    5800H
# Radeon Ryzen 9 5900H                                 2755.000000              Unknown      AMD                    5900H
# Radeon Ryzen 5 4600H                                 2343.000000              Unknown      AMD                    4600H
# Radeon Pro 450                                       2454.000000              Unknown      AMD                      450
# Radeon Ryzen 5 5600H                                 2541.500000              Unknown      AMD                    5600H
# Radeon Ryzen 9 4900H                                 2699.500000              Unknown      AMD                    4900H
# Ryzen 7 5700GE with Radeon Graphics                  2675.000000              Unknown      AMD                   5700GE
# Radeon Pro                                           2615.000000              Unknown      AMD            Unknown model
# Intel UHD 770                                        2611.000000              Unknown    Intel                  UHD 770
# Radeon Ryzen 7 PRO 4750G                             2643.000000              Unknown      AMD                    4750G
# GeForce GTX 950M                                     2602.000000               Mobile   Nvidia                     950M
# Ryzen 5 5600GE with Radeon Graphics                  2602.000000              Unknown      AMD                   5600GE
# Radeon Ryzen 7 4700G                                 2549.000000              Unknown      AMD                    4700G
# GeForce GTX 850M                                     1833.000000               Mobile   Nvidia                     850M
# GeForce MX330                                        2547.000000              Unknown   Nvidia                    MX330
# Radeon Ryzen 5 5600G                                 2570.000000              Unknown      AMD                    5600G
# Intel UHD P630                                       2541.000000              Unknown    Intel                 UHD P630
# Ryzen 9 5980HS with Radeon Graphics                  2534.000000              Unknown      AMD                   5980HS
# GeForce MX250                                        2515.000000              Unknown   Nvidia                    MX250
# Radeon Ryzen 7 4700GE                                2502.000000              Unknown      AMD                   4700GE
# GeForce GTX 950A                                     2483.000000              Unknown   Nvidia                     950A
# Radeon Pro WX 3200                                   2456.000000               Mobile      AMD                     3200
# Radeon Ryzen 5 PRO 4650G                             2406.500000              Unknown      AMD                    4650G
# GeForce GTX 960A                                     2411.000000              Unknown   Nvidia                     960A
# Ryzen 3 5300GE with Radeon Graphics                  2386.000000              Unknown      AMD                   5300GE
# GeForce GTX 580M                                     2373.000000               Mobile   Nvidia                     580M
# Radeon Ryzen 5 PRO 5650GE                            2434.500000              Unknown      AMD                   5650GE
# GeForce GTX 485M                                     2360.000000               Mobile   Nvidia                     485M
# Ryzen 3 PRO 5350GE with Radeon Graphics              2341.000000              Unknown      AMD                   5350GE
# GeForce GTX 675MX                                    2338.000000               Mobile   Nvidia                    675MX
# Radeon Ryzen 7 PRO 5850U                             2348.000000              Unknown      AMD                    5850U
# Radeon Ryzen 7 5800U                                 2394.000000              Unknown      AMD                    5800U
# GeForce MX150                                        2310.000000               Mobile   Nvidia                    MX150
# Radeon Ryzen 3 4300GE                                2354.000000              Unknown      AMD                   4300GE
# Ryzen 5 PRO 4400G with Radeon Graphics               2306.000000              Unknown      AMD                    4400G
# Radeon Ryzen 7 Microsoft Surface Edition             2298.000000              Unknown      AMD            Unknown model
# Ryzen 7 5700U with Radeon Graphics                   2289.000000              Unknown      AMD                    5700U
# Radeon R9 M470                                       2288.000000               Mobile      AMD                     M470
# Radeon Ryzen 7 4800U                                 2308.500000              Unknown      AMD                    4800U
# Radeon Ryzen 5 PRO 5650G                             2362.500000              Unknown      AMD                    5650G
# Radeon Ryzen 7 PRO 4750GE                            2375.000000              Unknown      AMD                   4750GE
# Radeon Ryzen 5 4600G                                 2124.000000              Unknown      AMD                    4600G
# Intel Iris Pro P580                                  2169.000000              Unknown    Intel            Iris Pro P580
# Radeon Ryzen 3 PRO 4350G                             2176.000000              Unknown      AMD                    4350G
# Radeon Ryzen 7 PRO 5750G                             2372.500000              Unknown      AMD                    5750G
# Radeon Ryzen Embedded V2718                          2149.000000              Unknown      AMD                    V2718
# Radeon Ryzen 5 PRO 5650U                             2161.000000              Unknown      AMD                    5650U
# Radeon Ryzen 7 4850U Mobile                          2138.000000              Unknown      AMD                    4850U
# Radeon TM R9 A360                                    2105.000000              Unknown      AMD                     A360
# Radeon Ryzen 5 Microsoft Surface Edition             2093.000000              Unknown      AMD            Unknown model
# GeForce GTX 480M                                     2051.000000               Mobile   Nvidia                     480M
# Radeon Ryzen 7 4700U                                 2038.500000              Unknown      AMD                    4700U
# Radeon Ryzen 5 PRO 4650GE                            2007.500000              Unknown      AMD                   4650GE
# Radeon Ryzen 7 PRO 4750U                             2026.000000              Unknown      AMD                    4750U
# Radeon R9 M385                                       2018.000000               Mobile      AMD                     M385
# Radeon Ryzen 5 5600U                                 2087.500000              Unknown      AMD                    5600U
# Radeon Pro W5500M                                    2010.000000               Mobile      AMD                   W5500M
# GeForce GT 645                                       2006.000000              Unknown   Nvidia                      645
# Ryzen 5 5500U with Radeon Graphics                   2001.000000              Unknown      AMD                    5500U
# Intel Iris Pro 580                                   1993.000000              Unknown    Intel             Iris Pro 580
# Intel Iris Xe MAX                                    1973.000000              Unknown    Intel              Iris Xe MAX
# GeForce GTX 765M                                     1972.000000               Mobile   Nvidia                     765M
# Radeon R9 M275X                                      1963.000000              Unknown      AMD                    M275X
# Intel UHD ReleaseInternal                            1959.000000              Unknown    Intel      UHD ReleaseInternal
# Radeon 550                                           1959.000000              Unknown      AMD                      550
# GeForce GTX 470M                                     1953.000000               Mobile   Nvidia                     470M
# GeForce 945M                                         1945.000000              Unknown   Nvidia                     945M
# Radeon Pro WX 4150                                   1935.000000               Mobile      AMD                     4150
# GeForce GTX 675M                                     2285.500000               Mobile   Nvidia                     675M
# Radeon R9 M385X                                      1929.000000               Mobile      AMD                    M385X
# GeForce GTX 570M                                     1910.000000               Mobile   Nvidia                     570M
# GeForce GTX 670MX                                    1906.000000               Mobile   Nvidia                    670MX
# GeForce MX130                                        1895.000000              Unknown   Nvidia                    MX130
# GeForce MX230                                        1884.000000              Unknown   Nvidia                    MX230
# Radeon Pro WX 4130                                   1881.000000               Mobile      AMD                     4130
# GeForce 945A                                         1852.000000              Unknown   Nvidia                     945A
# Intel Iris Plus                                      1850.000000              Unknown    Intel                Iris Plus
# Radeon Vega 11                                       2016.333333              Unknown      AMD                       11
# Radeon R9 M375X                                      1843.000000               Mobile      AMD                    M375X
# Radeon Ryzen 5 4600U                                 1876.500000              Unknown      AMD                    4600U
# Radeon Ryzen 5 4500U                                 1873.666667              Unknown      AMD                    4500U
# Ryzen 3 PRO 4200G with Radeon Graphics               1799.000000              Unknown      AMD                    4200G
# Embedded Radeon E9173                                1798.000000              Unknown      AMD                    E9173
# Intel Iris 650                                       1795.000000              Unknown    Intel                 Iris 650
# GeForce GTX 670M                                     1775.000000               Mobile   Nvidia                     670M
# Intel UHD 750                                        1775.000000              Unknown    Intel                  UHD 750
# Intel Iris Plus 655                                  1772.000000              Unknown    Intel            Iris Plus 655
# Radeon Pro WX 2100                                   1755.000000               Mobile      AMD                     2100
# Radeon R9 M360                                       1753.000000              Unknown      AMD                     M360
# Intel UHD P750                                       1744.000000              Unknown    Intel                 UHD P750
# Intel Iris Plus 645                                  1742.000000              Unknown    Intel            Iris Plus 645
# Radeon RX Vega11                                     1717.000000              Unknown      AMD            Unknown model
# Radeon Ryzen 3 PRO 4200GE                            1748.000000              Unknown      AMD                   4200GE
# Radeon Ryzen 5 PRO 4650U                             1697.500000              Unknown      AMD                    4650U
# GeForce GTX 760M                                     1691.000000               Mobile   Nvidia                     760M
# Radeon Vega 9                                        1669.000000              Unknown      AMD            Unknown model
# Intel Iris Pro P6300                                 1654.000000              Unknown    Intel           Iris Pro P6300
# Radeon E8860                                         1626.000000              Unknown      AMD                    E8860
# Ryzen 3 5300U with Radeon Graphics                   1626.000000              Unknown      AMD                    5300U
# Radeon R7 M465X                                      1624.000000              Unknown      AMD                    M465X
# Ryzen 7 2700U with Radeon Vega                       1617.000000              Unknown      AMD                    2700U
# GeForce GT 755M                                      1610.000000               Mobile   Nvidia                     755M
# Radeon Ryzen 3 4300G                                 1749.500000              Unknown      AMD                    4300G
# Radeon Vega 8                                        1593.000000      Desktop, Mobile      AMD            Unknown model
# Intel UHD                                            1582.000000              Unknown    Intel                      UHD
# Intel Iris Plus 650                                  1575.000000               Mobile    Intel            Iris Plus 650
# Radeon Vega 10                                       1572.000000              Unknown      AMD                       10
# Intel UHD 730                                        1553.000000              Unknown    Intel                  UHD 730
# Radeon RX Vega 8                                     1552.000000              Unknown      AMD            Unknown model
# Radeon RX 640                                        1551.000000      Desktop, Mobile      AMD                      640
# Radeon Ryzen 3 PRO 4450U                             1521.500000              Unknown      AMD                    4450U
# GeForce 940MX                                        1503.000000              Unknown   Nvidia                    940MX
# Ryzen 5 2500U with Radeon Vega                       1503.000000              Unknown      AMD                    2500U
# Radeon R9 M365X                                      1183.000000               Mobile      AMD                    M365X
# GeForce MX110                                        1469.000000              Unknown   Nvidia                    MX110
# Radeon Ryzen 3 PRO 4350GE                            1822.500000              Unknown      AMD                   4350GE
# Ryzen 5 PRO 4400GE with Radeon Graphics              1442.000000              Unknown      AMD                   4400GE
# Radeon Vega 8 Mobile                                 1438.000000              Unknown      AMD            Unknown model
# GeForce 845M                                         1430.000000               Mobile   Nvidia                     845M
# Radeon 550X                                          1430.000000              Unknown      AMD                     550X
# Intel Iris Pro Graphics 6200                         1429.000000              Unknown    Intel   Iris Pro Graphics 6200
# Radeon R7 M370                                       1418.000000               Mobile      AMD                     M370
# GeForce GTX 660M                                     1414.000000               Mobile   Nvidia                     660M
# Radeon Ryzen 5 4600GE                                1412.000000              Unknown      AMD                   4600GE
# Radeon Pro WX 4170                                   1409.000000               Mobile      AMD                     4170
# Radeon Ryzen 3 PRO 5350G                             1874.500000              Unknown      AMD                    5350G
# Radeon Ryzen 3 5300G                                 1814.500000              Unknown      AMD                    5300G
# Radeon 540X                                          1601.000000              Unknown      AMD                     540X
# Radeon R7 PRO A12-8870                               1376.000000              Unknown      AMD                 A12-8870
# Radeon R9 M370X                                      1374.000000               Mobile      AMD                    M370X
# Intel Iris 550                                       1344.000000              Unknown    Intel                 Iris 550
# Intel Iris Plus 640                                  1333.000000               Mobile    Intel            Iris Plus 640
# GeForce GT 750M                                      1313.000000               Mobile   Nvidia                     750M
# Radeon R7 PRO A8-8670E                               1310.000000              Unknown      AMD                 A8-8670E
# Radeon Ryzen 3 4300U                                 1400.333333              Unknown      AMD                    4300U
# GeForce 930MX                                        1302.000000               Mobile   Nvidia                    930MX
# TENSOR 1.0 Driver Intel HD 630                       1300.000000              Unknown    Intel  1.0 Driver Intel HD 630
# Radeon Ryzen Embedded V2748                          1296.000000              Unknown      AMD                    V2748
# Radeon Vega 6                                        1296.000000              Unknown      AMD            Unknown model
# Intel UHD 630                                        1293.000000              Unknown    Intel                  UHD 630
# Radeon R7 A370                                       1281.000000              Unknown      AMD                     A370
# Radeon R7 A10-7870K                                  1280.000000              Unknown      AMD                A10-7870K
# Radeon 540                                           1273.000000              Unknown      AMD                      540
# GeForce GTX 560M                                     1266.000000               Mobile   Nvidia                     560M
# Intel Iris 540                                       1257.000000              Unknown    Intel                 Iris 540
# Radeon 630                                           1245.000000              Unknown      AMD                      630
# Intel HD P630                                        1237.000000              Unknown    Intel                  HD P630
# GeForce GPU                                          1236.000000               Mobile   Nvidia            Unknown model
# Radeon R9 M270X                                      1204.000000               Mobile      AMD                    M270X
# Intel HD P530                                        1202.000000              Unknown    Intel                  HD P530
# GeForce GT 650M                                      1199.000000               Mobile   Nvidia                     650M
# GeForce GTX 460M                                     1198.000000               Mobile   Nvidia                     460M
# Radeon Ryzen 3 5400U                                 1458.500000              Unknown      AMD                    5400U
# GeForce 840A                                         1180.000000              Unknown   Nvidia                     840A
# Radeon R7 Opteron X3421                              1169.000000              Unknown      AMD                    X3421
# Intel Coffee Lake UHD                                1158.000000              Unknown    Intel          Coffee Lake UHD
# Radeon 625                                           1150.000000              Unknown      AMD                      625
# GeForce 940A                                         1145.000000              Unknown   Nvidia                     940A
# GeForce GT 745A                                      1144.000000              Unknown   Nvidia                     745A
# Radeon Ryzen 3 PRO 5450U                             1349.500000              Unknown      AMD                    5450U
# Radeon R7 FX-9830P RADEON                            1127.000000              Unknown      AMD                 FX-9830P
# Intel HD 630                                         1118.000000              Unknown    Intel                   HD 630
# Radeon R7 PRO A12-9800                               1053.000000              Unknown      AMD                 A12-9800
# Radeon R9 M275                                       1115.000000               Mobile      AMD                     M275
# Radeon R7 430                                        1021.666667              Unknown      AMD                      430
# Intel UHD 710                                        1107.000000              Unknown    Intel                  UHD 710
# GeForce 940M                                         1106.000000               Mobile   Nvidia                     940M
# GeForce GT 545                                       1096.000000              Unknown   Nvidia                      545
# GeForce 920MX                                        1088.000000              Unknown   Nvidia                    920MX
# GeForce 930A                                         1082.000000              Unknown   Nvidia                     930A
# GeForce 840M                                         1067.000000               Mobile   Nvidia                     840M
# GeForce GTX 760A                                     1060.000000              Unknown   Nvidia                     760A
# GeForce GT 745M                                      1055.000000               Mobile   Nvidia                     745M
# GeForce GTX 850A                                     1050.000000              Unknown   Nvidia                     850A
# Radeon R7 PRO A8-9600                                 923.500000              Unknown      AMD                  A8-9600
# Radeon 535                                           1048.000000              Unknown      AMD                      535
# Radeon R7 A12-9730P RADEON                           1047.000000              Unknown      AMD                A12-9730P
# Radeon R7 M460                                       1038.000000              Unknown      AMD                     M460
# Radeon Vega 3 Mobile                                 1029.000000              Unknown      AMD            Unknown model
# Radeon R7 M350                                       1027.000000              Unknown      AMD                     M350
# Radeon R9 A375                                       1024.000000              Unknown      AMD                     A375
# Intel Iris Pro 5200                                  1020.000000              Unknown    Intel            Iris Pro 5200
# GeForce 930M                                         1011.000000              Unknown   Nvidia                     930M
# GeForce 830A                                         1005.000000              Unknown   Nvidia                     830A
# Radeon R5 340                                         963.500000              Unknown      AMD                      340
# Intel HD 530                                          984.000000              Unknown    Intel                   HD 530
# GeForce 830M                                          976.000000               Mobile   Nvidia                     830M
# Radeon R7 M465                                        965.000000              Unknown      AMD                     M465
# Radeon R7 M270DX                                      962.000000              Unknown      AMD                   M270DX
# Radeon R7 PRO A12-8870E                               962.000000              Unknown      AMD                A12-8870E
# GeForce GT 645M                                       958.000000               Mobile   Nvidia                     645M
# Radeon R7 A10 PRO-7850B                               887.000000              Unknown      AMD                      A10
# Radeon R6 Opteron X3418                               955.000000              Unknown      AMD                    X3418
# Radeon R7 A265                                        955.000000              Unknown      AMD                     A265
# Radeon R7 A8-7500                                     948.000000              Unknown      AMD                  A8-7500
# Radeon R7 M260X                                       947.000000               Mobile      AMD                    M260X
# Radeon 530                                            945.000000              Unknown      AMD                      530
# Radeon R7 PRO A10-8850B                               945.000000              Unknown      AMD                A10-8850B
# zxcvIntel HD 620                                      944.000000              Unknown    Intel                   HD 620
# Radeon R7 PRO A12-9800E                               940.500000              Unknown      AMD                A12-9800E
# Radeon R7 PRO A10-9700E                              1035.500000              Unknown      AMD                A10-9700E
# Radeon R7 PRO A10-8770                                931.000000              Unknown      AMD                 A10-8770
# Radeon R9 M265X                                       929.000000               Mobile      AMD                    M265X
# Radeon. HD 7730M                                      928.000000              Unknown      AMD                    7730M
# Intel Iris Pro 6100                                   925.000000              Unknown    Intel            Iris Pro 6100
# Intel HD Graphics 620                                 923.000000              Unknown    Intel          HD Graphics 620
# Radeon R9 M280X                                       922.000000               Mobile      AMD                    M280X
# Radeon R7 A8-8650                                     913.000000              Unknown      AMD                  A8-8650
# Radeon R7 M445                                        913.000000              Unknown      AMD                     M445
# Radeon R7 A10-7860K                                   912.000000              Unknown      AMD                A10-7860K
# Radeon 6750M                                          911.000000              Unknown      AMD                    6750M
# GeForce GT 640M                                       907.000000               Mobile   Nvidia                     640M
# Intel Iris 6100                                       907.000000              Unknown    Intel                Iris 6100
# Radeon R7 PRO A10-8770E                               897.000000              Unknown      AMD                A10-8770E
# Intel UHD 620                                         889.000000              Unknown    Intel                  UHD 620
# Radeon Vega 3                                         889.000000              Unknown      AMD            Unknown model
# Radeon R7 A10-8750                                    885.000000              Unknown      AMD                 A10-8750
# Radeon R7 PRO A12-8830B                               883.000000              Unknown      AMD                A12-8830B
# GeForce GT 445M                                       881.000000               Mobile   Nvidia                     445M
# Radeon E6760                                          877.000000              Unknown      AMD                    E6760
# GeForce 920A                                          872.000000              Unknown   Nvidia                     920A
# Radeon R7 G                                           870.000000              Unknown      AMD            Unknown model
# Intel HD 520                                          866.000000              Unknown    Intel                   HD 520
# Radeon R7 A8-7670K                                    866.000000              Unknown      AMD                 A8-7670K
# Radeon R7 M440                                        862.000000              Unknown      AMD                     M440
# GeForce GT 635                                        852.000000              Unknown   Nvidia                      635
# Intel HD 6000                                         851.000000              Unknown    Intel                  HD 6000
# Intel UHD 617                                         848.000000              Unknown    Intel                  UHD 617
# Radeon R5 435                                         841.000000              Unknown      AMD                      435
# Radeon 620                                            840.000000              Unknown      AMD                      620
# Radeon 520                                            833.000000              Unknown      AMD                      520
# Intel HD 5200                                         830.000000              Unknown    Intel                  HD 5200
# Radeon R7 M260DX                                      822.000000              Unknown      AMD                   M260DX
# GeForce GT 730M                                       816.000000               Mobile   Nvidia                     730M
# Radeon 535DX                                          813.000000              Unknown      AMD                    535DX
# Radeon R5 A6-7480                                     811.000000              Unknown      AMD                  A6-7480
# Radeon R8 M445DX                                      806.000000              Unknown      AMD                   M445DX
# Radeon R5 M435                                        796.000000              Unknown      AMD                     M435
# Radeon R7 A8-7600                                     782.000000              Unknown      AMD                  A8-7600
# Radeon R7 A10-7890K                                   781.000000              Unknown      AMD                A10-7890K
# Radeon R7 A365                                        781.000000              Unknown      AMD                     A365
# GeForce GT 740M                                       779.000000               Mobile   Nvidia                     740M
# Radeon R7 FX-8800P                                    775.000000              Unknown      AMD                 FX-8800P
# RadeonT Vega 3                                        775.000000              Unknown      AMD            Unknown model
# Radeon R7 A10-8850                                    773.000000              Unknown      AMD                 A10-8850
# Radeon R7 PRO A10-9700                                873.000000              Unknown      AMD                 A10-9700
# GeForce 730A                                          756.000000              Unknown   Nvidia                     730A
# GeForce 825M                                          769.000000               Mobile   Nvidia                     825M
# Radeon R9 M375                                        763.000000               Mobile      AMD                     M375
# Intel UHD 615                                         760.000000              Unknown    Intel                  UHD 615
# Radeon R7 A12-9720P RADEON                            759.000000              Unknown      AMD                A12-9720P
# Intel Iris 5100                                       758.000000              Unknown    Intel                Iris 5100
# Radeon R7 PRO A10-8750B                               758.000000              Unknown      AMD                A10-8750B
# Radeon R7 PRO A10-9700B                               758.000000              Unknown      AMD                A10-9700B
# Radeon R7 A8-7680                                     752.000000              Unknown      AMD                  A8-7680
# Radeon M535DX                                         750.000000              Unknown      AMD                   M535DX
# Radeon R7 A10-7700K                                   749.000000              Unknown      AMD                A10-7700K
# Radeon R8 M365DX                                      741.000000              Unknown      AMD                   M365DX
# Radeon R7 PRO A8-8650B                                740.000000              Unknown      AMD                 A8-8650B
# Intel Poison Ivy                                      739.000000              Unknown    Intel               Poison Ivy
# Radeon R7 M270                                        734.000000              Unknown      AMD                     M270
# Intel UHD 610                                         729.000000              Unknown    Intel                  UHD 610
# Radeon R7 FX-9800P RADEON                             727.000000              Unknown      AMD                 FX-9800P
# GeForce 720A                                          725.000000              Unknown   Nvidia                     720A
# Intel HD 615                                          724.000000              Unknown    Intel                   HD 615
# GeForce 920M                                          723.000000              Unknown   Nvidia                     920M
# Radeon R7 PRO A12-9800B                               722.000000              Unknown      AMD                A12-9800B
# Asus GTX 650 FML II EC-EGPU                           721.000000              Unknown   Nvidia                      650
# Radeon R5 A10-9600P RADEON R5, 10 COMPUTE CORES 4C    716.000000              Unknown      AMD                A10-9600P
# Intel HD 5600                                         712.000000              Unknown    Intel                  HD 5600
# Radeon R7 A8-7650K                                    704.000000              Unknown      AMD                 A8-7650K
# Radeon R7 A12-9700P RADEON                            703.000000              Unknown      AMD                A12-9700P
# GeForce GT 740A                                       702.000000              Unknown   Nvidia                     740A
